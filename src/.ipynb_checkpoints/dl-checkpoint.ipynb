# %% [markdown]
# # Preparation

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import warnings; warnings.simplefilter('ignore')
import re

import pickle

# NLTK
import nltk
import codecs
from nltk.tokenize import PunktSentenceTokenizer,sent_tokenize, word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer, PorterStemmer
# nltk.download("stopwords")
# nltk.download("punkt")
# nltk.download("wordnet")

# Spacy
import spacy
nlp = spacy.load('en_core_web_lg', disable=["parser", "ner"])

# %% [markdown]
# ## Loading data

# %%
dataset_name = "main" + "_data"
djurdja_paths = {"dataset": str("~/pycharm/zavrsni/data/" + dataset_name + ".csv"),
                 "labels": "/home/ikrizanic/pycharm/zavrsni/data/labels.txt"}
local_paths = {"dataset": str("/home/ivan/Documents/git_repos/Sentiment-Analysis-on-Twitter/data/" + dataset_name + ".csv"),
               "labels": "/home/ivan/Documents/git_repos/Sentiment-Analysis-on-Twitter/data/labels.txt"}


raw_data_merge = pd.read_csv(local_paths["dataset"], sep="\t", names=["label", "text"])
emoticons_file = pd.read_csv('../data/emoticons.txt', sep="  ->  ", names=["emoji", "meaning"])

# %%
def remove_duplicates(csv_data):
    clean_data = dict()
    for i in tqdm((range(len(csv_data)))):
        if csv_data.text[i] not in clean_data and isinstance(csv_data.text[i], str):
            clean_data.update({csv_data.text[i]: csv_data.label[i]})
    return clean_data

data = remove_duplicates(raw_data_merge)

tweets = list()
labels = list()

for text in data.keys():
    tweets.append(text)
    
for polarity in data.values():
    if polarity == "positive":
        labels.append(2)
    elif polarity == "neutral":
        labels.append(1)
    else:
        labels.append(0)
        
labels.pop(0)
# Out:
# 100%|██████████| 40256/40256 [00:02<00:00, 18851.73it/s]
# 0

# %%
print(len(labels))
len(tweets)
# Out:
# 39607
# 39608

# %% [markdown]
# # Special functions

# %% [markdown]
# ## Tokenize

# %%
import spacy
nlp = spacy.load('en_core_web_lg', disable=["parser", "ner"])

# %%
def tokenize(raw, tokenizer="split"):
    if tokenizer == "spacy":
        return [token.text for token in nlp.tokenizer(raw)]
    if tokenizer == "split":
        return raw.split(" ")

# %% [markdown]
# # Hooks

# %% [markdown]
# ## Pretokenization

# %% [markdown]
# ### Removing links

# %%
def remove_links(raw):
    return re.sub(r'http.*\b', '[URL]', raw)

# %% [markdown]
# ### Repairing some lost characters

# %%
def repaire_chars(raw):
    raw = re.sub(r'\\u2019', "\'", raw)
    raw = re.sub(r'\\u002c', ',', raw)
    raw = re.sub(r'&lt', '>', raw)
    raw = re.sub(r'&gt', '<', raw)        
    raw = re.sub(r'&amp;', '&', raw)
    raw = re.sub(r'\\\"\"', '', raw)
    raw = re.sub(r'\"\"\\', '', raw)
    return raw

# %% [markdown]
# ### Removing usernames

# %%
def remove_usernames(raw):
    return re.sub(r'@[^\s]*', '[USER]', raw)

# %% [markdown]
# ### Replacing unuseful emoticons

# %%
def replace_unuseful_emoticons(raw):
    for k,v in EMOTICONS.items():
        if k in useful_emoticons.keys() and k in raw:
            raw.replace(k,v)
    return raw

# %% [markdown]
# ### Annotation and normalization (from github)

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons


text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['url', 'email', 'percent', 'money', 'phone', 'user',
        'time', 'url', 'date', 'number'],
    # terms that will be annotated
    annotate={"hashtag", "allcaps", "elongated", "repeated",
        'emphasis', 'censored'},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=True,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...

# %%
def annotation_normalization(raw):
    return " ".join(text_processor.pre_process_doc(raw))

# %% [markdown]
# ### Remove punctation

# %%
import string
def remove_punctuation(raw):
    return raw.translate(str.maketrans('', '', string.punctuation))

# %% [markdown]
# ### Spell check (from github)

# %%
import csv
import nltk
from ekphrasis.classes.spellcorrect import SpellCorrector
from nltk.corpus import words

djurdja = "/home/ikrizanic/pycharm/zavrsni/data/slang.csv"
local = "/home/ivan/Documents/git_repos/Sentiment-Analysis-on-Twitter/data/slang.csv"

with open(local, mode='r') as infile:
    reader = csv.reader(infile, delimiter=';')
    slang_dict = dict(reader)

sp = SpellCorrector(corpus="english")
nltk.download("words")
words = set(words.words())
punctuations = '''!()-[]{};:\'"\,<>./?@#$%^&*_~'''
# Out:
# Reading english - 1grams ...
# [nltk_data] Downloading package words to /home/ivan/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
def spell_check(raw):
    correct_raw = list()
    for word in raw.split(" "):
        if word in words:
            correct_raw.append(word)
        else:
            correct_raw.append(sp.correct(word))
    return " ".join(correct_raw)

# %% [markdown]
# ## Posttokenization

# %% [markdown]
# ### Spell check on tokens

# %%
def spell_check_tokens(tokens):
    correct_tokens = list()
    for token in tokens:
        if token.strip()[0] == "<":
            continue
        if token.strip()[0] in punctuations:
            continue
        if token.strip() in words:
            correct_tokens.append(token.strip())
        else:
            correct_tokens.append(sp.correct(token.strip()))
    return correct_tokens

# %% [markdown]
# ### Replace slang

# %%
def replace_slang(tokenized):
    tokens = []
    for token in tokenized:
        if token not in words:
            for key, value in slang_dict.items():
                if str(key).lower() == str(token).lower():
                    token = value.split(" ")
            if type(token) is list:
                tokens.extend(token)
            else:
                tokens.append(token)
        else:
            tokens.append(token)
    return tokens

# %% [markdown]
# ### Removing stopwords

# %%
def remove_stopwords(tokens):
    stop_words_set = set(stopwords.words('english'))
    new_tokens = []
    for token in tokens:
        token_lower = token if token.islower() else token.lower()
        if token_lower not in stop_words_set:
            new_tokens.append(token)
    return new_tokens

# %% [markdown]
# ### Lemmatizer

# %%
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer() 

def lemmatize(tokens):
    lem = list()
    for token in tokens:
        lem.append(lemmatizer.lemmatize(token))
    return lem

# %% [markdown]
# ### Build vocab

# %%
def build_vocab(data):
    vocab = dict()
    index = 1
    for sent in data:
        for word in sent:
            if word not in vocab.keys():
                vocab.update({word: index})
                index += 1     
    return vocab

# %% [markdown]
# ### Encode sentence

# %%
def encode_sentence(sentence, vocab):
    encoded = list()
    for word in sentence:
        encoded.append(vocab[word])
    return encoded

# %%
def encode_data(data, vocab):
    encoded_data = list()
    for sent in data:
        encoded_data.append(encode_sentence(sent, vocab))
    return encoded_data

# %% [markdown]
# # Data loading

# %% [markdown]
# ## Loading dataset

# %% [markdown]
# ### New dataset

# %%
import copy
dataset_raw = list()

for i in tqdm(range(len(tweets) - 1)):
    new_tweet = repaire_chars(tweets[i+1])
    anot = copy.deepcopy(new_tweet)
    
    new_tweet = remove_usernames(new_tweet)
    new_tweet = remove_links(new_tweet)
    new_tweet = remove_punctuation(new_tweet)
    
    tweet_tokens = tokenize(new_tweet, tokenizer="spacy")
    tweet_tokens = remove_stopwords(tweet_tokens)
    
    anot = annotation_normalization(anot)
    anot_tokens = tokenize(anot, tokenizer="split")
    anot_tokens = spell_check_tokens(anot_tokens)
    anot_tokens = replace_slang(anot_tokens)
    anot_tokens = remove_stopwords(anot_tokens)
    anot_tokens = lemmatize(anot_tokens)
    
    
    
    dataset_raw.append({"tweet": new_tweet, "tweet_tokens": tweet_tokens, "anot": anot, "anot_tokens": anot_tokens})
#     dataset.append({"tweet": new_tweet, "anot_tokens": anot_tokens})
# Out:
# 100%|██████████| 19/19 [00:00<00:00, 168.65it/s]

# %% [markdown]
# ### Pickle

# %% [markdown]
# #### Load data

# %%
import pickle
# load_file = open("/home/ikrizanic/pycharm/zavrsni/data/dataset_dump.pkl", "rb")
load_file = open("/home/ivan/Documents/git_repos/Sentiment-Analysis-on-Twitter/data/dataset_dump.pickle", "rb")
dataset_raw = pickle.load(load_file)
load_file.close()

# %% [markdown]
# #### Dump data

# %%
file = open("/home/ivan/Documents/git_repos/Sentiment-Analysis-on-Twitter/data/dataset_dump.pickle", "wb")
pickle.dump(dataset_raw, file)
file.close()

# %% [markdown]
# ### Print data

# %%
for d in dataset_raw:
#     print(d["tweet"])
#     print(d["tweet_tokens"])
#     print(d["anot"])
    print(d["anot_tokens"])
#     print(" ".join(d["anot_tokens"]))
#     print("="*50)
# Out:
# ['forgot', 'sad', 'first', 'episode', 'th', 'season', 'dexter', 'depressing', 'dexter', 'dark', 'passenger']
# ['oct', 'almost', 'far', 'away', 'wait', 'return', 'dexter']
# ['topic', 'episode', 'first', 'disk', 'dexter', 'please', 'hurry', 'fit', 'web', 'log']
# ['finally', 'catching', 'dexter', 'season', 'almost', 'finished', 'season', 'today', 'home', 'ill']
# ['downloaded', 'first', 'season', 'dexter', 'going', 'start', 'watching', 'episode', 'time', 'tweet', 'twit', 'twit']
# ['let', 'u', 'see', 'wrap', 'season', 'three', 'dexter', 'tonight', 'episode', 'go', 'till', 'season', 'finale', 'roll', 'series', 'four', 'please']
# ['retweet', 'st', 'rule', 'code', 'get', 'caught', 'dexter']
# ['word', 'tonight', 'night', 'dexter']
# ['honestly', 'say', 'dexter', 'good', 'show', 'may', 'order', 'showtime']
# ['feel', 'obliged', 'discus', 'dexter', 'tonight', 'living', 'large', 'brighton', 'please', 'use', 'direct', 'message']
# ['make', 'sure', 'girl', 'watch', 'season', 'dexter', 'season', 'premiere', 'season', 'best']
# ['addicted', 'dexter', 'new', 'almost', 'done', 'season', 'got', 'thursday']
# ['barely', 'going', 'sleep', 'watching', 'dexter', 'evening', 'love', 'show']
# ['beer', 'chicken', 'night', 'watching', 'dexter', 'till', 'working', 'hour', 'maybe', 'reserve', 'nickname', 'dexter', 'might', 'fun']
# ['enjoying', 'night', 'dexter']
# ['finally', 'starting', 'th', 'season', 'dexter', 'see', 'ya', 'later', 'weekend']
# ['fuck', 'everyone', 'else', 'dexter', 'friend', 'tonight', 'bring', 'season']
# ['complete', 'th', 'season', 'dexter', 'available', 'dvd', 'today', 'could', 'watch', 'demand']
# ['yeah', 'boy', 'entourage', 'tonight', 'pissed', 'epodes', 'end', 'oh', 'well', 'side', 'dexter', 'season', 'start', 'soon', 'ish']
# ['going', 'tuesday', 'house', 'blue', 'see', 'ap', 'rocky']
# ['real', 'dilemma', 'tomorrow', 'ap', 'rocky', 'concert', 'phoenix', 'got', 'called', 'back', 'start', 'working', 'tomorrow', 'bianchi']
# ['whoever', 'going', 'ap', 'rocky', 'wit', 'th', 'better', 'buy', 'ticket', 'like', 'today', 'think', "I'm", 'going', 'get', 'mine', 'soon']
# ['want', 'go', 'ap', 'rocky', 'concert', 'th', 'th', 'choice', 'taking', 'going']
# ['see', 'dallas', 'fan', 'ap', 'rocky', 'email', 'u', 'great', 'oppo', 'attend', 'show', 'hob', 'fri']
# ['coming', 'weekend', 'super', 'excited', 'playing', 'blue', 'stage', 'sat', 'night', 'right', 'ap', 'rocky']
# ['mom', 'said', 'yes', 'go', 'ap', 'rocky', 'concert', 'excited']
# ['look', 'like', 'brother', 'going', 'see', 'ap', 'rocky', 'tomorrow', 'sigh', 'life', 'need', 'stop', 'significantly', 'better', 'mine']
# ['may', 'ask', 'cool', 'ap', 'rocky']
# ['oooh', 'yha', 'dmc', 'ap', 'rocky', 'one', 'th']
# ['merril', 'hoge', 'stupid', 'sick', 'hearing', 'tebow', 'may', 'right', 'took', 'aaron', 'rodgers', 'year', 'start']
# ['retweet', 'possible', 'aaron', 'rodgers', 'suffer', 'career', 'ending', 'injury', 'tonight', 'curious']
# ['aaron', 'rodgers', 'jersey', 'battery', 'room', 'windmill', 'bagnoli', 'web', 'log', 'designer', 'wedding', 'dress', 'sale']
# ['first', 'play', 'night', 'aaron', 'rodgers', 'int', 'uefa', 'come', 'back', 'brandan', 'ross', 'return', 'pick', 'six', 'touchdown']
# ['da', 'way', 'aaron', 'rodgers', 'lookin', 'greenbay', 'may', 'take']
# ['retweet', 'tuning', 'charger', 'linked', 'two', 'game', 'pkg', 'see', 'aaron', 'rodgers', 'got', 'buy', 'ticket']
# ['finished', 'qbs', 'draft', 'today', 'got', 'pick', 'first', 'every', 'time', 'take', 'arian', 'foster', 'roddy', 'white', 'jason', 'witten', 'n', 'aaron', 'rodgers']
# ['sensationalism', 'finest', 'next', 'thing', 'know', 'hearing', 'graham', 'harrell', 'may', 'take', 'aaron', 'rodgers', 'spot', 'shaking', 'head']
# ['aaron', 'rodgers', 'may', 'best', 'qb', 'nfl', 'still', 'improving', 'yahoo', 'sport', 'nigga', 'fuck', 'team']
# ['aaron', 'rodgers', 'totally', 'air', 'practice', 'routine', 'medium', 'today', 'must', 'good', 'champion', 'packer']
# ['need', 'ryan', 'leaf', 'got', 'show', 'retweet', 'aaron', 'rodgers', 'kurt', 'warner', 'kyle', 'kendrick', 'jungle', 'tomorrow']
# ['brown', 'force', 'aaron', 'rodgers', 'packer', 'go', 'st', 'possession', 'brown', 'better', 'steelers', 'one', 'thing', 'least']
# ['saw', 'photo', 'aaron', 'rodgers', 'awesome', 'scruff', 'going', 'today', 'mention', 'white', 'house', 'today', 'cool']
# ['far', 'drafted', 'aaron', 'rodgers', 'overall', 'round', 'matt', 'forte', 'bad']
# ['score', 'may', 'aaron', 'rodgers', 'kept', 'right', 'statistically', 'favre', 'damn', 'skol', 'viking']
# ['today', 'day', 'waiting', 'summer', 'day', 'see', 'aaron', 'rodgers', 'field', 'excited', 'packer']
# ['kanis', 'bukas', 'na', 'pala', 'first', 'day', 'nice', 'game', 'secret', 'love', 'sungkyunkwan', 'scandal', 'sa', 'ab', 'cbn', 'eh', 'may', 'pasok', 'kami', 'bukas', 'diane', 'naman', 'oh']
# ['mark', 'date', 'miss', 'earth', 'coronation', 'night', 'sat', 'live', 'starworld', 'free', 'television', 'broadcast', 'sun', 'ab', 'cbn']
# ['taking', 'nap', 'pm', 'going', 'ab', 'cbn', 'flight', 'tomorrow', 'hassle', 'pare']
# ['saw', 'last', 'ab', 'cbn', 'hallway']
# ['sungkyunkwan', 'scandal', 'ab', 'cbn', 'finished', 'series', 'yesterday', 'may', 'sound', 'like', 'spoiler', 'evil', 'laugh']
# ['wow', 'thank', 'tanduay', 'may', 'replay', 'ang', 'tanduay', 'rockfest', 'sa', 'ab', 'cbn', 'best', 'rock', 'pilipinas']
# ['noon', 'today', 'know', 'count', 'tune', 'ab', 'cbn', 'see', 'st', 'tvc', 'biggest', 'brightest', 'bpo', 'employer', 'ph', 'convergys']
# ['everyone', 'please', 'watch', 'soon', 'possible', 'ab', 'cbn', 'sunday', 'see', 'beautiful']
# ['november', 'super', 'tour', 'rockwell', 'ten', 'ab', 'cbn', 'friday', 'market', 'meet', 'super', 'tuyo', 'friend', 'see']
# ['thank', 'ab', 'cbn', 'cwm', 'fantastic', 'episode', 'today', 'tomorrow', 'wait']
# ['arrival', 'ship', 'arabian', 'tahr', 'port', 'abu', 'dhabi', 'time', 'utc', 'time', 'arrival', 'departure', 'time', 'vessel', 'application']
# ['arrival', 'ship', 'mata', 'pride', 'port', 'abu', 'dhabi', 'time', 'utc', 'time', 'arrival', 'departure', 'time', 'vessel', 'appr']
# ['arrival', 'ship', 'nm', 'port', 'abu', 'dhabi', 'time', 'utc', 'time', 'arrival', 'departure', 'time', 'vessel', 'approach']
# ['arrival', 'ship', 'sham', 'port', 'abu', 'dhabi', 'time', 'utc', 'time', 'arrival', 'departure', 'time', 'vessel', 'approach']
# ['departure', 'ship', 'al', 'dhafra', 'port', 'abu', 'dhabi', 'time', 'utc', 'time', 'arrival', 'departure', 'time', 'vessel', 'application']
# ['departure', 'ship', 'Ask', 'something', 'port', 'abu', 'dhabi', 'time', 'utc', 'time', 'arrival', 'departure', 'time', 'vessel', 'approx']
# ['departure', 'ship', 'arabian', 'oryx', 'port', 'abu', 'dhabi', 'time', 'utc', 'time', 'arrival', 'departure', 'time', 'vessel']
# ['departure', 'ship', 'jumbo', 'spirit', 'port', 'abu', 'dhabi', 'time', 'utc', 'time', 'arrival', 'departure', 'time', 'vessel']
# ['departure', 'ship', 'sham', 'port', 'abu', 'dhabi', 'time', 'utc', 'time', 'arrival', 'departure', 'time', 'vessel', 'approach']
# ['departure', 'ship', 'stanford', 'provider', 'port', 'abu', 'dhabi', 'time', 'utc', 'time', 'arrival', 'departure', 'time', 'f']
# ['may', 'win', 'academy', 'award', 'freaking', 'people', 'choice', 'dammit']
# ['suggesting', 'sake', 'completeness', 'la', 'polaris', 'deadline', 'academy', 'award', 'dec']
# ['seen', 'lawless', 'guy', 'pearce', 'get', 'oscar', 'nomination', 'may', 'possibly', 'give', 'academy', 'award']
# ['actor', 'academy', 'award', 'recording', 'artist', 'grammys', 'dj', 'gsa', 'nominee', 'announced', 'tomorrow']
# ['seth', 'mcfarlane', 'set', 'host', 'th', 'academy', 'award', 'february', 'think', 'choice']
# ['st', 'academy', 'award', 'ceremony', 'presented', 'academy', 'motion', 'picture', 'art', 'science', 'ampas', 'honored']
# ['clown', 'broken', 'record', 'become', 'st', 'film', 'win', 'brazilian', 'academy', 'award', 'yesterday']
# ['today', 'answer', 'stone', 'received', 'academy', 'award', 'work', 'film', 'midnight', 'express', 'platoon', 'born', 'fourth', 'july']
# ['would', 'company', 'like', 'sponsor', 'rd', 'annual', 'pnc', 'bank', 'non', 'profit', 'academy', 'award', 'see', 'attached', 'detail']
# ['st', 'black', 'woman', 'ever', 'host', 'academy', 'award', 'want', 'like', 'black', 'history', 'moment']
# ['fuck', 'sat', 'act']
# ['want', 'take', 'act', 'tomorrow']
# ['talking', 'act', 'sat', 'deciding', 'want', 'go', 'college', 'applying', 'college', 'everything', 'college', 'stress']
# ['registering', 'act', 'sat', 'last', 'minute', 'tired']
# ['addicted', 'act', 'took', 'one', 'saturday', 'signed', 'third', 'test']
# ['oh', 'right', 'dig', 'going', 'act', 'tomorrow', 'night', 'tho', 'lounging']
# ['also', 'need', 'least', 'accredited', 'act', 'rebt', 'end', 'th', 'yr']
# ['finished', 'signing', 'sat', 'act']
# ['oh', 'man', 'thought', 'deadline', 'act', 'tomorrow', 'th', 'bless']
# ['knew', 'adidas', 'deal', 'u', 'like', 'undecided', 'u', 'watching', 'game', 'sat', 'trying', 'get']
# ['cause', 'agent', 'say', 'want', 'continue', 'adidas', 'go', 'office', 'monday', 'day', 'go', 'alr', 'ask', 'quick']
# ['year', 'Instant', 'Message', 'still', 'lookin', 'shaking', 'head', 'may', 'go', 'adidas', 'store', 'asian', 'dude', 'wear', 'em']
# ['think', 'ill', 'bring', 'monday', 'adidas']
# ['bring', 'adidas', 'sock', 'tomorrow']
# ['got', 'job', 'mall', 'time', 'get', 'job', 'adidas', 'tomorrow']
# ['make', 'bid', 'adidas', 'predator', 'tomorrow', 'godwilling']
# ['going', 'upwards', 'kid', 'played', 'well', 'sunday', 'night', 'prop', 'friend', 'adidas']
# ['even', 'though', 'nike', 'x', 'better', 'adidas', 'still', 'going', 'adidas', 'employee', 'store', 'tomorrow']
# ['oh', 'post', 'big', 'adidas', 'warehouse', 'sale', 'tomorrow', 'interested']
# ['donkey', 'show', 'opening', 'tomorrow', 'adrienne', 'arsht', 'center', 'get', 'ticket', 'today']
# ['friday', 'talib', 'kweli', 'idle', 'warship', 're', 'adrienne', 'arsht', 'center']
# ['hip', 'hop', 'fan', 'talibkweli', 'idle', 'warship', 're', 'fri', 'adrienne', 'arsht', 'center', 'performing', 'art']
# ['got', 'tomorrow', 'wood', 'adrienne', 'arsht', 'center', 'performing', 'art']
# ['join', 'u', 'donkey', 'show', 'adrienne', 'arsht', 'center', 'performing', 'art', 'friday', 'save', 'ticket']
# ['photo', 'rock', 'age', 'sneaker', 'th', 'season', 'adrienne', 'arsht', 'center']
# ['disco', 'ball', 'polished', 'ready', 'thursday', 'night', 'join', 'u', 'adrienne', 'arsht', 'center']
# ['thursday', 'ticket', 'special', 'pre', 'screening', 'event', 'donkey', 'show', 'adrienne', 'arsht', 'center']
# ['uploading', 'random', 'picture', 'laughing', 'loud', 'last', 'sunday', 'show', 'adrienne', 'arsht', 'center']
# ['donkey', 'show', 'friday', 'th', 'exciting', 'day', 'adrienne', 'arsht', 'center', 'performing', 'art']
# ['rd', 'one', 'dropped', 'afghan', 'put', 'pressure', 'ind', 'v', 'away', 'game']
# ['vandal', 'oakland', 'night', 'sf', 'afghan', 'grown']
# ['afghan', 'protest', 'french', 'cartoon', 'u', 'film', 'hundred', 'afghan', 'thursday', 'protested', 'first', 'time']
# ['rediff', 'live', 'hundred', 'afghan', 'thursday', 'protested', 'first', 'time', 'cartoon', 'prophet', 'moham']
# ['wicket', 'getting', 'worse', 'afghan', 'slipped', 'karim', 'sadiq', 'run', 'jos', 'buttler', 'th']
# ['pakistan', 'talk', 'counterterrorism', 'u', 'afghan', 'pakistan', 'foreign', 'minister', 'revealed', 'thursday', 'country', 'would', 'soon', 'hold', 'co']
# ['taken', 'come', 'friday', 'afghan', 'saturday', 'guaranteed']
# ['afghan', 'halal', 'meat', 'shop', 'may', 'well', 'amount', 'afghan', 'halal', 'meat', 'house']
# ['yesterday', 'laughing', 'loud', 'alotta', 'afghan', 'birthday', 'yesterday', 'isnt', 'even', 'happy', 'birthday']
# ['skyline', 'drive', 'shenandoah', 'w', 'rambam', 'tomorrow', 'afghan', 'park', 'sunday', 'unique', 'laughing', 'loud']
# ['people', 'left', 'world', 'one', 'bill', 'murray', 'people', 'th']
# ['haha', 'get', 'serious', 'may', 'want', 'call', 'original', 'ghost', 'hunter', 'bill', 'murray', 'ghostbusters']
# ['thinking', 'outfit', 'like', 'nick', 'lounge', 'singer', 'bill', 'murray', 'old', 'old', 'saturday', 'night', 'live', 'maybe', 'sherbet', 'tux']
# ['bill', 'murray', 'yeah', 'monday', 'meet', 'infinity', 'ward', 'next', 'game', 'modern', 'warfare', 'Instant', 'Message', 'work', 'sequel', 'mw']
# ['c', 'mon', 'avila', 'got', 'tagged', 'guy', 'look', 'like', 'kid', 'bill', 'murray', 'researching', 'royal', 'tenenbaums', 'tiger']
# ['tom', 'hank', 'bill', 'murray', 'may', 'two', 'people', 'would', 'like', 'meet', 'well', 'scarlett', 'johansen', 'different', 'reason', 'though']
# ['columbus', 'shoot', 'bill', 'murray', 'zombieland', 'may', 'one', 'funniest', 'thing', 'ever']
# ['bruce', 'willis', 'bill', 'murray', 'ed', 'norton', 'film', 'may', 'faint']
# ['may', 'spend', 'lot', 'free', 'time', 'riding', 'random', 'elevator', 'hoping', 'chance', 'encounter', 'bill', 'murray']
# ['cu', 'friday', 'reason', 'bill', 'murray', 'awesome']
# ['mostly', 'dead', 'mostly', 'dead', 'still', 'little', 'bit', 'alive', 'billy', 'crystal', 'princess', 'bride']
# ['helicopter', 'may', 'wicked', 'billy', 'crystal', 'going', 'going', 'great']
# ['danny', 'seem', 'lot', 'like', 'billy', 'crystal', 'first', 'rd', 'harry', 'met', 'sally']
# ['see', 'sound', 'like', 'saw', 'billy', 'crystal', 'mr', 'saturday', 'night', 'yes']
# ['billy', 'crystal', 'attends', 'special', 'th', 'anniversary', 'screening', 'princess', 'bride', 'new', 'york', 'festival']
# ['meg', 'ryan', 'make', 'sunday', 'underpants', 'billy', 'crystal', 'mr', 'god', 'blank', 'stare', 'harry', 'met', 'sally']
# ['got', 'ticket', 'late', 'show', 'david', 'letterman', 'air', 'tonight', 'look', 'u', 'rd', 'row', 'billy', 'crystal', 'guest']
# ['love', 'billy', 'crystal', 'introducing', 'st', 'game', 'world', 'series']
# ['watching', 'harry', 'met', 'sally', 'love', 'movie', 'New', 'York', 'City', 'b', 'billy', 'crystal', 'meg', 'ryan', 'perfect', 'start', 'friday']
# ['yelawolf', 'still', 'best', 'yelawolf', 'billy', 'crystal', 'feat', 'rockit', 'screen', 'lyric', 'via', 'dgi', 'tjustbecause', 'took', 'th']
# ['billy', 'cundiff', 'missed', 'f**king', 'gay', 'end', 'quarter', 'changed', 'game', 'never', 'play']
# ['may', 'kick', 'tribe', 'called', 'quest', 'answering', 'text', 'billy', 'cundiff']
# ['closest', 'source', 'fan', 'team', 'way', 'heard', 'card', 'may', 'sign', 'billy', 'cundiff', 'truth', 'snark', 'life']
# ['mt', 'baltimore', 'sun', 'reporting', 'redskin', 'cundiff', 'ed', 'billy', 'cundiff']
# ['baltimore', 'team', 'mascot', 'come', 'missing', 'st', 'person', 'interest', 'billy', 'cundiff', 'redskin', 'mascot', 'taken', 'blame']
# ['look', 'steelers', 'fan', 'know', 'may', 'upset', 'suisham', 'missing', 'kick', 'know', 'heard', 'guy', 'named', 'billy', 'cundiff', 'available']
# ['pain', 'far', 'deeper', 'billy', 'cundiff', 'missed', 'field', 'goal', 'got', 'wake', 'forget', 'tomorrow', 'oriole', 'stay', 'hungry']
# ['per', 'team', 'source', 'redskin', 'bring', 'kicker', 'workout', 'tomorrow', 'billy', 'cundiff', 'poor']
# ['billy', 'cundiff', 'may', 'leaving', 'washington', 'hopefully', 'miss', 'door', 'way']
# ['president', 'talking', 'growing', 'economy', 'like', 'billy', 'cundiff', 'explaining', 'someone', 'make', 'field', 'goal', 'th', 'quarter']
# ['two', 'birthday', 'cake', 'one', 'jelly', 'bean', 'wonder', 'kind', 'birthday', 'cake', 'one', 'goodnight', 'kina', 'emi', 'misa']
# ['according', 'radio', 'rihanna', 'birthday', 'cake', 'official', 'th', 'july', 'anthem', 'sound', 'right']
# ['since', 'tomorrow', 'birthday', 'going', 'listen', 'every', 'song', 'word', 'birthday', 'birthday', 'cake', 'birthday', 'girl']
# ['tomorrow', 'get', 'make', 'birthday', 'cake']
# ['case', 'enough', 'plenty', 'birthday', 'cake', 'ready', 'tomorrow']
# ['still', 'want', 'birthday', 'cake', 'remix', 'wanted', 'saturday']
# ['girl', 'birthday', 'cake', 'birthday', 'song', 'video', 'somebody', 'bring', 'house', 'thursday']
# ['little', 'girl', 'singing', 'birthday', 'cake', 'girl', 'yo', 'th', 'birthday', 'day', 'shaking', 'head', 'laughing', 'loud']
# ['better', 'enjoy', 'turkey', 'pumpkin', 'pie', 'birthday', 'cake', 'day', 'monday', 'best', 'way', 'celebrate', 'legal', 'wait']
# ['birthday', 'cake', 'going', 'song', 'leading', 'u', 'th', 'quarter', 'count']
# ['almost', 'bkk', 'sleep', 'game', 'st', 'time', 'lost', 'ref']
# ['saturday', 'dont', 'even', 'came', 'side', 'much', 'bkk', 'con', 'upset']
# ['since', 'et', 'went', 'via', 'bkk', 'th', 'freedom', 'right', 'load', 'unload', 'pax', 'indirect', 'flight']
# ['please', 'transfer', 'money', 'tomorrow', 'want', 'success', 'social', 'medium', 'town', 'bkk', 'big', 'project', 'minseok']
# ['myanmar', 'saturday', 'work', 'tom', 'spark', 'pr', 'bkk', 'event', 'saturday', 'yangon', 'visa']
# ['last', 'push', 'last', 'day', 'training', 'break', 'bkk', 'thursday']
# ['hello', 'marie', 'stay', 'bkk', 'may', 'god', 'bless']
# ['yes', 'doable', 'bkk', 'night', 'flew', 'europe', 'morning']
# ['looking', 'forward', 'watching', 'sometime', 'soon', 'bkk', 'super', 'friday', 'weekend', 'ahead', 'lotsa', 'love']
# ['thanks', 'came', 'today', 'thanks', 'love', 'tonight', 'bkk', 'bound', 'see', 'ya', 'party', 'people', 'next', 'wednesday', 'thank', 'god', 'friday', 'ghetto']
# ['Instant', 'Message', 'going', 'black', 'dahlia', 'tomorrow', 'one', 'going', 'get', 'everyone', 'stupid']
# ['buck', 'see', 'dethklok', 'machine', 'head', 'remains', 'black', 'dahlia', 'murder', 'may', 'go', 'see', 'show']
# ['bloodfeast', 'return', 'stage', 'killafornia', 'new', 'act', 'predomination', 'join', 'friday', 'black', 'dahlia']
# ['come', 'check', 'black', 'dahlia', 'saturday', 'night', 'going', 'party']
# ['okay', 'going', 'dethklok', 'black', 'dahlia', 'murder', 'remains', 'oakland']
# ['polar', 'dust', 'hitting', 'black', 'dahlia', 'boksburg', 'th', 'november', 'click', 'event', 'detail']
# ['deathmatch', 'number', 'send', 'pic', 'dress', 'wearing', 'wednesday', 'perfect', 'black', 'dahlia']
# ['haha', 'black', 'dahlia', 'favorite', 'song', 'miss', 'still', 'going', 'miss', 'may']
# ['dethklok', 'tour', 'coming', 'chattanooga', 'machine', 'head', 'black', 'dahlia', 'murder', 'atr', 'going']
# ['omfgomfgomfgomfg', 'black', 'dahlia', 'murder', 'machine', 'head', 'dethklok', 'remains', 'going', 'palladium', 'november', 'boy']
# ['need', 'chill', 'wait', 'unleash', 'aggression', 'black', 'dahlia', 'murder', 'tomorrow', 'going', 'end', 'life']
# ['present', 'dethklok', 'machine', 'head', 'remains', 'black', 'dahlia', 'murder', 'tuesday', 'november', 'th', 'venue', 'hub']
# ['excited', 'cannibal', 'corpse', 'seen', 'devildriver', 'twice', 'st', 'time', 'corpse', 'oh', 'black', 'dahlia', 'murder']
# ['dethklok', 'remains', 'machine', 'head', 'black', 'dahlia', 'murder', 'pacquiao', 'versus', 'marquez', 'fight', 'december']
# ['dethklok', 'remains', 'machine', 'head', 'black', 'dahlia', 'murder', 'stage', 'ae', 'highly', 'considering', 'going', 'heavy', 'metal']
# ['jamming', 'aa', 'miss', 'may', 'black', 'dahlia', 'murder', 'day', 'rage']
# ['que', 'present', 'dethklok', 'machine', 'head', 'remains', 'black', 'dahlia', 'murder', 'tuesday', 'november', 'th']
# ['angry', 'comment', 'coming', 'back', 'december', 'lamb', 'god', 'couple', 'day', 'later', 'dethklok', 'coming', 'black', 'dahlia', 'murder', 'stoked']
# ['wear', 'black', 'dahlia', 'murder', 'shirt', 'one', 'day', 'sun', 'dress', 'next']
# ['dethklok', 'remains', 'black', 'dahlia', 'murder', 'november', 'dig']
# ['ufo', 'alien', 'black', 'triangle', 'sighting', 'pompano', 'beach', 'florida', 'basically', 'blended', 'wit']
# ['alternative', 'news', 'black', 'triangle', 'sighting', 'tucson', 'arizona', 'red', 'circle', 'triangle', 'cut']
# ['black', 'triangle', 'sighting', 'oranjestad', 'black', 'triangle', 'ufo', 'resemblance', 'stealth']
# ['black', 'triangle', 'sighting', 'perryton', 'texas', 'black', 'object', 'obscured', 'sky', 'star']
# ['ufo', 'sighting', 'black', 'triangle', 'sighting', 'oranjestad', 'black', 'triangle', 'ufo', 'resemblance']
# ['ufo', 'sighting', 'black', 'triangle', 'sighting', 'perryton', 'texas', 'dark', 'triangle', 'shape', 'across', 'spawn', 'kill']
# ['ufo', 'sighting', 'black', 'triangle', 'sighting', 'perryton', 'texas', 'black', 'object', 'obscured']
# ['yes', 'u', 'black', 'triangle', 'sighting', 'plainfield', 'illinois', 'large', 'triangle', 'alien']
# ['yes', 'u', 'black', 'triangle', 'sighting', 'pompano', 'beach', 'florida', 'basically', 'alien']
# ['yes', 'u', 'black', 'triangle', 'sighting', 'olmsted', 'fall', 'ohio', 'triangular', 'sape', 'alien']
# ['respect', 'retweet', 'boehner', 'asks', 'obama', 'move', 'speech', 'thursday']
# ['boehner', 'tell', 'obama', 'sorry', 'house', 'booked', 'maybe', 'come', 'another', 'day']
# ['boehner', 'want', 'obama', 'move', 'speech', 'wed', 'thurs', 'next', 'week', 'due', 'gop', 'debate', 'wed', 'sense', 'urgency', 'american', 'suffer']
# ['boehner', 'want', 'president', 'change', 'speech', 'thurs', 'instead', 'going', 'gop', '2012', 'debate', 'time', 'packer', 'saint', 'nfl', 'opener']
# ['damn', 'someone', 'saved', 'holder', 'earthquake', 'technically', 'dont', 'know', 'w', 'biden', 'obama', 'always', 'boehner', 'rd', 'line']
# ['retweet', 'boehner', 'want', 'president', 'change', 'speech', 'thurs', 'instead', 'going', 'gop', '2012', 'debate', 'time', 'packer']
# ['gop', 'greatest', 'crime', 'boehner', 'proposes', 'obama', 'speech', 'night', 'nfl', 'opening', 'night']
# ['smoker', 'boehner', 'got', 'wanted', 'fact', 'dow', 'today', 'boehner', 'owns', 'every', 'point', 'pee', 'pee', 'fok', 'maddow', 'tea', 'party']
# ['boehner', 'sent', 'letter', 'tweeted', 'yesterday', 'one', 'cantor']
# ['boehner', 'proposes', 'obama', 'speech', 'night', 'nfl', 'opening', 'night']
# ['boehner', 'reject', 'th', 'invite', 'obama', 'th', 'nfl', 'opening', 'night', 'obama', 'speak', 'wh', 'th', 'save', 'football', 'coverage']
# ['truly', 'love', 'party', 'boehner', 'schedule', 'obama', 'address', 'night', 'gop', 'debate']
# ['mt', 'boehner', 'asks', 'obama', 'move', 'speech', 'thurs', 'forget', 'u', 'w', 'u', 'tues', 'work']
# ['retweet', 'retweet', 'golf', 'ball', 'pelosi', 'face', 'allegedly', 'distributed', 'boehner', 'fundraiser', 'today', 'hyper', 'text', 'transfer', 'protocol']
# ['retweet', 'boehner', 'proposes', 'obama', 'speech', 'night', 'nfl', 'opening', 'night']
# ['retweet', 'golf', 'ball', 'pelosi', 'face', 'allegedly', 'distributed', 'boehner', 'fundraiser', 'today', 'sick']
# ['nice', 'disagreement', 'course', 'sat', 'boehner', 'thi']
# ['hide', 'country', 'club', 'u', 'want', 'boehner', 'reverserobocall', 'com', 'launching', 'soon', 'one', 'st', 'line', 'join', 'launch']
# ['good', 'morning', 'killa', 'pick', 'georgia', 'boise', 'state', 'game', 'saturday']
# ['yo', 'man', 'want', 'wear', 'dawgs', 'jersey', 'boise', 'state', 'jersey', 'going', 'fashion', 'ugadawgswag']
# ['boise', 'state', 'may', 'make', 'brandon', 'boykin', 'day', 'via', 'uga', 'dawgs', 'boise', 'georgia', 'bulldog']
# ['morning', 'paper', 'georgia', 'get', 'ready', 'big', 'opener', 'needed', 'boise', 'state', 'look', 'kicker', 'bangle']
# ['retweet', 'program', 'alert', 'debate', 'whether', 'boise', 'state', 'win', 'check', 'show', 'today']
# ['retweet', 'damn', 'becomes', 'rd', 'back', 'ajayi', 'retweet', 'boise', 'state', 'rb', 'malcolm', 'johnson', 'tore', 'acl', 'practice', 'yesterday']
# ['retweet', 'called', 'boise', 'state', 'tried', 'get', 'schedule', 'north', 'carolina', 'monday', 'night', 'mickey', 'matthew']
# ['retweet', 'football', 'season', 'preview', 'show', 'start', 'airing', 'tonight', 'mtn', 'half', 'hour', 'program', 'latest', 'boise', 'state']
# ['yeah', 'bright', 'side', 'got', 'letter', 'boise', 'state', 'yesterday']
# ['boise', 'state', 'jersey', 'game', 'saturday', 'sick', 'dissapointed']
# ['girl', 'singing', 'national', 'anthem', 'tonight', 'boise', 'state', 'student', 'gave', 'go', 'duck', 'went', 'seem', 'faze']
# ['got', 'letter', 'today', 'one', 'wake', 'forest', 'university', 'boise', 'state']
# ['love', 'much', 'come', 'join', 'u', 'saturday', 'evening', 'uga', 'v', 'boise', 'state', 'game', 'game']
# ['ideal', 'world', 'oregon', 'boise', 'state', 'win', 'give', 'power', 'pac', 'way', 'go', 'duck']
# ['retweet', 'zag', 'hold', 'lead', 'minute', 'beat', 'boise', 'state', 'win', 'bronco', 'invite', 'goal', 'sarah', 'rhodes', 'rd']
# ['night', 'dream', 'uga', 'beat', 'boise', 'state', 'let', 'u', 'hope', 'come', 'true']
# ['way', 'bolton', 'stubborn', 'talking', 'demanding', 'stupid', 'fee', 'expecting', 'jim', 'sign', 'today']
# ['see', 'bolton', 'later', 'today', 'weekend', 'typical', 'timing', 'ever']
# ['gutted', 'match', 'bolton', 'tomorrow', 'well']
# ['wish', 'bolton', 'tonight']
# ['please', 'retweet', 'bolton', 'society', 'blind', 'people', 'bringing', 'vega', 'bolton', 'charity', 'dinner', 'bsp']
# ['able', 'perform', 'cold', 'summer', 'day', 'bolton', 'sunday', 'probably']
# ['please', 'retweet', 'bolton', 'society', 'blind', 'people', 'bringing', 'vega', 'bolton', 'charity', 'dinner']
# ['thinking', 'going', 'tomorrow', 'moving', 'onto', 'bolton', 'get', 'city', 'eagle']
# ['bolton', 'society', 'blind', 'people', 'bringing', 'vega', 'bolton', 'charity', 'dinner', 'please', 'retweet', 'xx', 'bsp']
# ['paddy', 'mcguinness', 'morning', 'continuing', 'show', 'old', 'stereotype', 'broadcaster', 'bolton', 'shout', 'time']
# ['retweet', 'day', 'work', 'tomorrow', 'bolton', 'first', 'away', 'season', 'mcmcfmcfcok']
# ['know', 'sky', 'reporting', 'tonight', 'everton', 'bolton', 'also', 'interested', 'according', 'twitter', 'search']
# ['seen', 'goal', 'city', 'win', 'bolton', 'need', 'get', 'day', 'back', 'man', 'hope', 'play', 'tomorrow', 'top', 'player']
# ['bolton', 'th', 'form', 'college', 'level', 'celebration', 'tonight', 'include', 'watching', 'dvd', 'staying', 'dog', 'bottle', 'vodka', 'wild']
# ['bolton', 'away', 'tomorrow', 'hope', 'get', 'game', 'quality', 'pre', 'season', 'blue']
# ['gym', 'tonight', 'dependent', 'erm', 'fresh', 'kit', 'otherwise', 'pilgrimage', 'bolton', 'first', 'saturday', 'morning', 'feeling', 'good']
# ['reckon', 'match', 'bolton', 'man', 'city', 'good', 'tomorrow', 'football', 'season']
# ['ironman', 'uk', 'bolton', 'highlight', 'tomorrow', 'channel', 'watch', 'back', 'od', 'hope', 'get', 'sneaky', 'glimpse']
# ['agency', 'incl', 'bomb', 'squad', 'needed', 'dispose', 'hazardous', 'waste', 'e', 'th', 'st', 'post', 'rd']
# ['thursday', 'lady', 'night', 'come', 'get', 'thirsty', 'thursday', 'bomb', 'squad']
# ['last', 'u', 'school', 'come', 'said', 'next', 'member', 'bomb', 'squad', 'th', 'grader', 'sam', 'bruce', 'nephew', 'isaac', 'bruce', '2016', 'prospect']
# ['well', 'monsoon', 'coming', 'north', 'bomb', 'squad', 'midtown', 'th', 'time', 'go']
# ['bomb', 'squad', 'bake', 'sale', 'thursday', 'th', 'miss']
# ['excitement', 'danger', 'estatales', 'found', 'old', 'wwii', 'shell', 'inert', 'spent', 'time', 'bomb', 'squad', 'monday']
# ['good', 'morning', 'bomb', 'squad', 'family', 'hope', 'lovely', 'saturday']
# ['gumby', 'may', 'answer', 'forward', 'woe', 'bomb', 'squad', 'never', 'stop', 'believing', 'never', 'stop', 'believing', 'gumby', 'release', 'gumby']
# ['happy', 'th', 'bomb', 'squad']
# ['okay', 'Instant', 'Message', 'twitter', 'night', 'til', 'tomorrow', 'bomb', 'squad', 'enjoy', 'ur', 'night', 'love', 'much']
# ['brit', 'award', 'winning', 'pop', 'star', 'mika', 'set', 'return', 'brand', 'new', 'album', 'origin', 'love', 'released', 'island', 'record']
# ['london', 'studio', 'tomorrow', 'morning', 'hope', 'one', 'mention', 'harry', 'brit', 'award', 'error']
# ['fact', 'st', 'table', 'one', 'direction', 'lifted', 'first', 'ever', 'brit', 'award', 'best', 'british', 'single']
# ['alright', 'win', 'brit', 'award', 'best', 'female', 'break', 'wind', 'may']
# ['realized', 'boy', 'brit', 'award', 'birthday', 'like', 'partying', 'time', 'recieved', 'bestia', 'thanks']
# ['look', 'far', 'come', 'since', 'smash', 'album', 'brit', 'award', 'even', 'beat', 'justin', 'bieber', 'tca']
# ['se', 'member', 'alresford', 'community', 'choir', 'share', 'stage', 'brit', 'award', 'winning', 'exciting']
# ['scoop', 'elmbridge', 'choir', 'performing', 'brit', 'award', 'classic', 'boy', 'band', 'blake', 'epsom', 'playhouse', 'yoohoo', 'cool']
# ['three', 'time', 'grammy', 'nominated', 'brit', 'award', 'nominee', 'ivor', 'novella', 'winner', 'joan', 'armatrading', 'take', 'stage', 'sunday']
# ['studio', 'working', 'new', 'album', 'sound', 'epic', 'may', 'well', 'pick', 'brit', 'award', 'honest']
# ['time', 'oscar', 'winner', 'john', 'williams', 'receive', 'lifetime', 'achievement', 'award', 'classical', 'brit', 'award', 'royal', 'albert', 'hall']
# ['russell', 'u', 'beat', 'laughing', 'loud', 'going', 'tweet', 'classical', 'brit', 'award', 'sunday']
# ['forget', 'classical', 'brit', 'award', 'tonight', 'special', 'appearance', 'th', 'anniversary', 'cast', 'phantom', 'th', 'birthday']
# ['laura', 'wright', 'gareth', 'malone', 'noah', 'stewart', 'margherita', 'taylor', 'attend', 'classic', 'brit', 'award', 'launch']
# ['laura', 'wright', 'gareth', 'malone', 'noah', 'stewart', 'margherita', 'taylor', 'attend', 'classic', 'brit', 'award']
# ['oh', 'God', 'ramin', 'sierra', 'performing', 'phantom', 'opera', 'classical', 'brit', 'award', 'televised', 'sunday', 'itv']
# ['haha', 'hardly', 'knew', 'one', 'day', 'house', 'sat', 'made', 'watch', 'brit', 'award']
# ['make', 'feel', 'gay', 'set', 'classical', 'brit', 'award', 'record', 'tomorrow', 'haha', 'oh', 'dear']
# ['glad', 'classical', 'brit', 'award', 'itv', 'sunday', 'set', 'record', 'button', 'case', 'forget', 'watch']
# ['nigga', 'hit', 'full', 'court', 'one', 'handed', 'shot', 'brook', 'lopez', 'shaking', 'head', 'st', 'birthday', 'shit']
# ['st', 'game', 'brooklyn', 'want', 'see', 'brook', 'lopez']
# ['brook', 'lopez', 'get', 'short', 'shot', 'brooklyn', 'net', 'lead', 'w', 'play', 'rd', 'quarter', 'hello', 'brooklyn']
# ['brook', 'lopez', 'scored', 'point', 'quarter', 'featured', 'net', 'joe', 'johnson', 'absent', 'play', 'half', 'net', 'national', 'basketball', 'association', '']
# ['brook', 'lopez', 'double', 'double', 'rd', 'net', 'nation']
# ['dont', 'look', 'brook', 'lopez', 'pt', 'reb', 'minute', 'st', 'game', 'back', 'foot', 'injury', 'weekend', 'minute', 'tonight']
# ["I'm", 'going', 'need', 'brook', 'lopez', 'get', 'aggressive', 'board', 'foot', 'tall', 'c', 'mon', 'son']
# ['av', 'offensive', 'rebound', 'minute', 'left', 'rd', 'good', 'month', 'brook', 'lopez']
# ['brook', 'lopez', 'best', 'offensive', 'center', 'national', 'basketball', 'association', '', 'as']
# ['son', 'deandre', 'learned', 'anything', 'dunking', 'could', 'rd', 'best', 'center', 'league', 'brook', 'lopez', 'rebound', 'number', 'hold', 'back']
# ['watching', 'cannavaro', 'even', 'embarrassing']
# ['although', 'one', 'time', 'finished', 'rd', 'cannavaro', 'finished', 'st', 'yes', 'fabio', 'cannavaro', 'bullshit']
# ['st', 'time', 'juventus', 'maximizing', 'potential', 'ex', 'milan', 'player', 'cannavaro', 'edgar', 'david', 'similar', 'case']
# ['tomorrow', 'fruit', 'cake', 'toronto', 'versus', 'liverpool', 'go', 'stadium', 'today', 'napoli', 'versus', 'bayern', 'scored', 'pandev', 'cannavaro', 'insigne']
# ['year', 'unspoken', 'remember', 'rubber', 'bracelet', 'may', 'may', 'dog', 'tag', 'cannavaro']
# ['drogba', 'report', 'suggest', 'preferred', 'start', 'cannavaro', 'anything', 'close', 'game', 'friday', 'take']
# ['buffon', 'cap', 'italy', 'behind', 'maldini', 'behind', 'leader', 'cannavaro', 'legend']
# ['st', 'time', 'since', 'italy', 'travel', 'major', 'tournament', 'without', 'franco', 'baresi', 'paolo', 'maldini', 'cannavaro', 'via']
# ['lost', 'match', 'since', 'last', 'year', 'consistent', 'never', 'forgetting', 'cannavaro', 'st', 'defender', 'win']
# ['saw', 'u', 'cannavaro', 'know', 'u', 'italy', 'congratulation', 'best', 'world', 'legend']
# ['rd', 'thought', 'careless', 'world', 'st', 'one']
# ['careless', 'world', 'tour', 'hit', 'place', 'cali', 'haha', 'fuck', 'yoo']
# ['st', 'episode', 'careless', 'world', 'television', 'europe', 'facebook', 'make', 'sure', 'give', 'like', 'team', 'tyga']
# ['remember', 'like', 'leaked', 'st', 'made', 'new', 'one', 'careless', 'world']
# ['ay', 'gone', 'release', 'hotelcalifornia', 'feb', 'like', 'careless', 'world']
# ['careless', 'world', 'album', 'year']
# ['tyga', 'careless', 'world', 'moving', 'five', 'spot', 'headed', 'th', 'week', 'ymca', 'rapper', 'lp', 'sold', 'record']
# ['ym', 'shit', 'right', 'finished', 'listening', 'human', 'going', 'onto', 'pink', 'friday', 'hello', 'careless', 'world']
# ['yo', 'followed', 'interested', 'un', 'tagged', 'verse', 'careless', 'world']
# ['listening', 'careless', 'world', 'rise', 'king', 'cannot', 'wait', 'rd', 'rack', 'city', 'bitch']
# ['dont', 'care', 'carling', 'cup', 'save', 'looserpool', 'yeah', 'lose', 'also', 'wont', 'cry', 'night', 'long', 'wednesday', 'night']
# ['think', 'chelsea', 'appeal', 'torres', 'red', 'card', 'let', 'sturridge', 'play', 'tomorrow', 'carling', 'cup', 'parent', 'looking']
# ['carling', 'cup', 'wednesday', 'extra', 'time', 'please', 'play', 'england', 'international', 'give', 'kid', 'rest', 'lfc', 'still', 'hat']
# ['carling', 'cup', 'previously', 'arsenal', 'played', 'string', 'even', 'could', 'count', 'bendtner', 'vela', 'grab', 'goal', 'national', 'basketball', 'association', '']
# ['liverpool', 'champion', 'carling', 'cup', 'last', 'season', 'kicked', 'rd', 'round', 'competition', 'swansea', 'anfield']
# ['bren', 'field', 'mate', 'joint', 'bottom', 'celebrated', 'like', 'carling', 'cup']
# ['another', 'chelsea', 'versus', 'manchester', 'united', 'today', 'th', 'round', 'carling', 'cup', 'miss']
# ['two', 'enjoyable', 'night', 'carling', 'cup', 'action', 'arsenal', 'last', 'night', 'cfc', 'quite', 'pathetic', 'really', 'v', 'reading', 'sunday', 'live']
# ['bbc', 'asking', 'last', 'night', 'carling', 'cup', 'th', 'round', 'tie', 'reading', 'arsenal', 'greatest', 'cup', 'tie', 'time', 'honestly']
# ['hate', 'say', 'think', 'go', 'penalty', 'tomorrow', 'feeling', 'like', 'carling', 'cup', 'final']
# ['went', 'st', 'match', 'last', 'match', 'carling', 'cup', 'final', 'die', 'liverpool']
# ['fa', 'cup', 'sf', 'carling', 'cup', 'final', 'lost', 'pen', 'may', 'true', 'leader', 'certainly', 'took', 'u', 'place']
# ['bird', 'dont', 'buy', 'sun', 'banner', 'carling', 'cup', 'final', 'mikey', 'dye', 'lfc', 'dont', 'buy', 'sun']
# ['bird', 'dont', 'buy', 'sun', 'banner', 'carling', 'cup', 'final', 'mikey', 'dye', 'dont', 'buy', 'sun']
# ['launched', 'day', 'carling', 'cup', 'final', 'see', 'dont', 'buy', 'sun', 'poster', 'dont', 'buy', 'sun', 'anyday', 'jft']
# ['last', 'laugh', 'get', 'carling', 'cup', 'final', 'result', 'may', 'vary']
# ['th', 'playoff', 'carling', 'cup', 'final', 'malky', 'mackay', 'literally', 'love', 'season']
# ['hat', 'trick', 'manu', 'close', 'carling', 'cup', 'final', 'goal']
# ['hope', 'fit', 'sunday', 'pt', 'arsenal', 'better', 'watching', 'carling', 'cup', 'final']
# ['flexthursday', 'dis', 'thursday', 'wit', 'crow', 'nest', 'call', 'da', 'whol', 'souf', 'kum', 'kick', 'wit', 'lincity']
# ['flexthursday', 'dis', 'thursday', 'wit', 'crow', 'nest', 'call', 'da', 'whol', 'souf', 'kum', 'kick', 'wit', 'lincity']
# ['flexthursday', 'dis', 'thursday', 'wit', 'crow', 'nest', 'call', 'da', 'whol', 'souf', 'kum', 'kick', 'wit', 'lincity']
# ['flexthursday', 'dis', 'thursday', 'wit', 'crow', 'nest', 'call', 'da', 'whol', 'souf', 'kum', 'kick', 'wit', 'flex']
# ['burger', 'blonde', 'friday', 'today', 'crow', 'nest', 'pure', 'blonde', 'burger', 'purchase']
# ['heading', 'crow', 'nest', 'sunday', 'cover', 'ray', 'white', 'celebration', 'year', 'business', 'real', 'estate']
# ['song', 'say', 'everything', 'break', 'rope', 'hang', 'neil', 'mcsweeney', 'dir', 'sat', 'johal', 'crow', 'nest', 'film']
# ['manly', 'market', 'mittagong', 'saturday', 'crow', 'nest', 'fair', 'kiama', 'market', 'sunday', 'hope', 'see']
# ['hung', 'housemate', 'awesome', 'went', 'crow', 'nest', 'festival', 'celebrated', 'dog', 'th', 'birthday', 'love', 'diesel', 'bean']
# ['say', 'eat', 'friday', 'care', 'thank', 'god', 'friday', 'galo', 'crow', 'nest']
# ['cundiff', 'still', 'kicker', 'come', 'sunday', 'starting', 'riot']
# ['wvu', 'go', 'every', 'th', 'kicker', 'worst', 'cundiff']
# ['national', 'th', 'inning', 'th', 'quarter', 'redskin', 'feel', 'coulda', 'swore', 'saw', 'cundiff', 'shank', 'one', 'mound']
# ['full', 'veteran', 'kicker', 'due', 'redskin', 'park', 'tomorrow', 'word', 'whether', 'run', 'cundiff', 'watch', 'go', 'wide', 'retweet']
# ['cundiff', 'got', 'released', 'think', 'outta', 'league', 'especially', 'quote', 'Tough', 'Luck', 'past', 'sunday', 'real']
# ['dirty', 'jim', 'close', 'one', 'may', 'started', 'hearing', 'comparison', 'cundiff', 'town']
# ['cundiff', 'would', 'made', 'field', 'goal', 'sunday', 'could', 'eatin', 'free', 'sub', 'subway', 'lunch']
# ['know', 'thats', 'Instant', 'Message', 'saying', 'laughing', 'loud', 'tucker', 'straight', 'outkicked', 'cundiff', 'camp', 'glad', 'gone', 'didnt', 'miss', 'one', 'th', 'qtr']
# ['rg', 'cleared', 'viking', 'game', 'sunday', 'good', 'mood', 'p', 'thank', 'god', 'got', 'rid', 'cunniff', 'cundiff']
# ['oh', 'shit', 'ray', 'lewis', 'may', 'able', 'come', 'back', 'hopefully', 'young', 'cause', 'ask', 'raven', 'would', 'superbowl', 'cundiff']
# ['much', 'easier', 'pretty', 'sure', 'tomorrow', 'cupid', 'shuffle', 'tho', 'hate']
# ['cupid', 'much', 'work', 'da', 'st', 'time', 'want', 'friend']
# ['reviewing', 'text', 'picture', 'thurs', 'sat', 'thinking', 'alcohol', 'liquid', 'form', 'cupid', 'fall', 'love', 'every', 'weekend', 'oops']
# ['cupid', 'psyche', 'original', 'greek', 'myth', 'story', 'golden', 'as', 'apuleius', 'often', 'cited', 'st', 'fairy', 'tale']
# ['sick', 'beard', 'download', 'finished', 'rd', 'rock', 'sun', 'xi', 'dick', 'put', 'id', 'cupid']
# ['someone', 'hitman', 'sure', 'may', 'hitman', 'dude', 'got', 'made', 'look', 'bad', 'cupid', 'co', 'hit', 'real', 'hard', 'man']
# ['hahaha', 'shut', 'cupid', 'yeah', 'hopefully', 'go', 'good', 'saturday', 'every', 'day']
# ['rumour', 'cupid', 'piece', 'string', 'friday', 'sure', 'saturday', 'rumour', 'funky', 'town', 'gants', 'hill', 'big', 'v']
# ['remember', 'cupid', 'conversation', 'last', 'year', 'bomb', 'candy', 'bar', 'liked', 'love', 'next', 'tuesday', 'tr']
# ['cupid', 'lie', 'know', 'unless', 'give', 'try', 'wowow', 'may', 'pinaghuhugutan']
# ['aw', 'hell', 'curtis', 'painter', 'coming', 'give', 'rd', 'conversion']
# ['curtis', 'painter', 'finally', 'going', 'get', 'shot', 'tonight', 'help', 'root', 'guy']
# ['curtis', 'painter', 'curtis', 'painter', 'last', 'night', 'fumble', 'one', 'walk', 'td', 'overthrown', 'yard']
# ['laughing', 'as', 'retweet', 'curtis', 'painter', 'look', 'like', 'kind', 'guy', 'would', 'try', 'buy', 'beer', 'sunday', 'scumbag']
# ['peyton', 'manning', 'curtis', 'painter', 'starting', 'sunday', 'going', 'lose', 'shit']
# ['colt', 'backup', 'qb', 'curtis', 'painter', 'warming', 'could', 'kerry', 'collins', 'may', 'concussion', 'nfl', 'colt']
# ['colt', 'start', 'painter', 'qb', 'monday', 'versus', 'bucs', 'curtis', 'painter', 'make', 'first', 'nfl', 'start', 'quarterback', 'th', 'link']
# ['curtis', 'painter', 'asked', 'interview', 'today', 'lead', 'singer', 'nirvana', 'getting', 'band', 'back', 'together']
# ['got', 'web', 'log', 'post', 'coming', 'tomorrow', 'topic', 'time', 'learn', 'curtis', 'painter', 'got', 'start', 'man', 'colt']
# ['minute', 'kerry', 'collins', 'colt', 'let', 'u', 'give', 'curtis', 'painter', 'shot', 'quarter']
# ['going', 'somber', 'set', 'tonight', 'curtis', 'painter', 'nickelback', 'cover', 'band', 'something', 'mouth']
# ['curtis', 'painter', 'chance', 'believe', 'kerry', 'collins', 'throw', 'u', 'pick', 'six', 'tonight']
# ['look', 'like', 'curtis', 'painter', 'era', 'colt', 'may', 'begin', 'tonight']
# ['kerry', 'collins', 'may', 'look', 'like', 'old', 'mouse', 'hold', 'ball', 'like', 'one', 'curtis', 'painter', 'experiment', 'really', 'much', 'better']
# ['retweet', 'curtis', 'painter', 'totally', 'going', 'get', 'lucky', 'tonight', 'probably', 'another', 'girl', 'look', 'like']
# ['takeaway', 'tonight', 'game', 'colt', 'run', 'defense', 'huge', 'curtis', 'painter', 'rightfully', 'owes', 'u', 'u', 'especially', 'big', 'finger']
# ['may', 'fact', 'retweet', 'curtis', 'painter', 'help', 'colt', 'win', 'first', 'game', 'u', 'heard', 'first']
# ['check', 'monday', 'highlight', 'daily', 'zap']
# ['check', 'monday', 'highlight', 'daily', 'zap']
# ['daily', 'zap', 'okc', 'versus', 'san', 'daily', 'zap', 'okc', 'versus', 'san', 'check', 'tonight', 'e', 'wait', 'presskit', 'ad']
# ['daily', 'zap', 'daily', 'zap', 'check', 'whip', 'around', 'league', 'highlight', 'ton']
# ['national', 'basketball', 'association', '', 'video', 'daily', 'zap', 'action', 'wednesday', 'six', 'pack', 'found', 'right', 'daily', 'zap', 'national', 'basketball', 'association', '']
# ['tip', 'season', 'w', 'tuesday', 'night', 'daily', 'zap']
# ['daily', 'zap', 'action', 'wednesday', 'six', 'pack', 'found', 'right', 'daily', 'zap']
# ['daily', 'zap', 'action', 'wednesday', 'six', 'pack', 'found', 'right', 'daily', 'zap', 'national', 'basketball', 'association', '']
# ['daily', 'zap', 'catch', 'highlight', 'monday', 'action', 'national', 'basketball', 'association', '']
# ['daily', 'zap', 'catch', 'highlight', 'thursday', 'action', 'national', 'basketball', 'association', '']
# ['stuck', 'dallas', 'airport', 'saturday', 'night', 'gettin', 'crazy', 'get', 'home']
# ['even', 'sxsw', 'last', 'yr', 'st', 'day', 'went', 'dallas', 'day', 'stump']
# ['whoa', 'well', 'break', 'bee', 'dallas', 'might', 'visit', 'november', 'december', 'march', 'thee', 'summer']
# ['okay', 'well', 'coming', 'back', 'dallas', 'tonight']
# ['r', 'going', 'dallas', 'friday', 'saturday']
# ['yes', 'dallas', 'event', 'remind', 'send', 'link', 'tomorrow', 'news', 'f**k', 'worth', 'event', 'none', 'tho']
# ['trying', 'go', 'tonight', 'go', 'dallas']
# ['dallas', 'ready', 'come', 'great', 'night', 'u', 'wait', 'blow', 'roof']
# ['good', 'luck', 'fun', 'think', 'dallas', 'today', 'fight', 'alzheimers']
# ['hope', 'life', 'tonight', 'love', 'mama', 'visit', 'dallas', 'soon']
# ['retweet', 'tonight', 'come', 'see', 'hottest', 'gogo', 'boy', 'dallas']
# ['reminds', 'best', 'night', 'life', 'retweet', 'dallas']
# ['win', 'lose', 'think', 'dallas', 'fan', 'would', 'agree', 'great', 'play', 'game', 'big', 'one', 'tonight', 'year', 'mediocrity']
# ['yep', 'might', 'b', 'move', 'dallas', 'tonight', 'retweet', 'true', 'would', 'b', 'fun']
# ['new', 'season', 'opener', 'dallas', 'star', 'thursday', 'probably', 'buy', 'ticket', 'yet', 'call', 'cynical']
# ['dj', 'king', 'suffered', 'broken', 'right', 'hand', 'fight', 'krys', 'barch', 'stable', 'versus', 'dallas', 'star', 'missed', 'month']
# ['tonight', 'obama', 'buffalo', 'sabre', 'mitt', 'dallas', 'star', 'may', 'seem', 'right']
# ['read', 'baron', 'schedule', 'right', 'said', 'play', 'dallas', 'star', 'home', 'sunday']
# ['dallas', 'star', 'forward', 'jamie', 'benn', 'signed', 'hamburg', 'freezer', 'germany', 'could', 'make', 'debut', 'mannheim', 'friday']
# ['get', 'ticket', 'detroit', 'red', 'wing', 'bus', 'trip', 'dallas', 'star']
# ['tonight', 'obama', 'buffalo', 'sabre', 'mitt', 'dallas', 'star', 'may', 'seem', 'right', 'sabre', 'fan', 'dallas', 'still']
# ['tonight', 'obama', 'buffalo', 'sabre', 'mitt', 'dallas', 'star', 'may', 'seem', 'right']
# ['flashback', 'friday', 'dallas', 'star', 'settle', 'victoriously', 'new', 'dig', 'aac', 'watch', 'first', 'game']
# ['wish', 'nhl', 'nhlpa', 'come', 'agreement', 'go', 'dallas', 'see', 'dallas', 'star', 'march']
# ['like', 'presale', 'tomorrow', 'show', 'dar', 'constitution', 'hall']
# ['anybody', 'want', 'dispatch', 'ticket', 'playing', 'next', 'thursday', 'dar', 'constitution', 'hall', 'good']
# ['going', 'see', 'estelle', 'sat', 'washington', 'care', 'dar', 'constitution', 'hall', 'check', 'tour', 'date']
# ['going', 'anthony', 'hamilton', 'dar', 'constitution', 'hall', 'washington', 'care']
# ['going', 'dar', 'constitution', 'hall', 'going', 'make', 'last', 'part', 'rhyme', 'bad']
# ['norfolk', 'va', 'norva', 'theatre', 'na', 'washington', 'care', 'dar', 'constitution', 'hall', 'concert', 'seeker']
# ['would', 'go', 'see', 'dar', 'constitution', 'hall', 'sunday', 'evening']
# ['think', 'go', 'nicki', 'concert', 'dar', 'constitution', 'hall', 'st', 'chainz', 'going', 'dere']
# ['hey', 'mindless', 'behavior', 'ur', 'concert', 'saturday', 'dar', 'constitution', 'hall', 'great', 'p']
# ['shaquille', 'neal', 'star', 'comedy', 'jam', 'dar', 'constitution', 'hall', 'sat', 'washington', 'care', 'look', 'like', 'great', 'show']
# ['never', 'sun', 'jo', 'never', 'even', 'guaranteed', 'date', 'dave', 'grohl', 'even']
# ['snuck', 'sunday', 'night', 'important', 'person', 'party', 'acl', 'got', 'meet', 'dave', 'grohl', 'party', 'open', 'bar', 'style']
# ['guy', 'sat', 'opposite', 'train', 'spit', 'dave', 'grohl']
# ['let', 'killing', 'joke', 'deal', 'sunday', 'night', 'blue', 'instead', 'dave', 'grohl', 'drum']
# ['queen', 'stone', 'age', 'dave', 'grohl', 'sat', 'stool', 'regular', 'john', 'glastonbury', 'song', 'deaf', 'tour']
# ['queen', 'stone', 'age', 'regular', 'john', 'glastonbury', 'song', 'deaf', 'tour', 'dave', 'grohl', 'sat', 'stool']
# ['older', 'brother', 'going', 'see', 'tenacious', 'sunday', 'dave', 'grohl', 'going', 'playing', 'drum']
# ['february', 'star', 'year', 'old', 'still', 'one', 'best', 'song', 'dave', 'grohl', 'ever', 'written', 'fact']
# ['fun', 'fact', 'th', 'grade', 'thought', 'dave', 'grohl', 'eddie', 'vedder', 'person']
# ['sat', 'birthday', 'listening', 'would', 'great', 'get', 'shout', 'guy', 'dave', 'grohl', 'legend']
# ['david', 'taylor', 'year', 'ago', 'whn', 'st', 'came', 'stl', 'went', 'apostle', 'hub', 'used', 'play', 'service']
# ['please', 'give', 'fan', 'treat', 'start', 'trash', 'talking', 'david', 'taylor', 'really', 'heat', 'thing', 'may', 'match', 'century']
# ['come', 'see', 'david', 'taylor', 'piopio', 'next', 'saturday']
# ['brand', 'new', 'updated', 'logo', 'edited', 'david', 'taylor', 'new', 'executive', 'producer', 'roc', 'television', 'first', 'introduction', 'video', 'tomorrow']
# ['check', 'live', 'jazz', 'music', 'david', 'taylor', 'tom', 'ogunribido', 'today', 'lpc', 'student', 'center', 'floor', 'dining', 'area']
# ['know', 'rule', 'could', 'stop', 'qld', 'playing', 'david', 'taylor', 'nrl', 'u', 'qld', 'play', 'taylor', 'tomorrow', 'origin']
# ['know', 'rule', 'could', 'stop', 'qld', 'playing', 'david', 'taylor', 'nrl', 'u', 'qld', 'play', 'taylor', 'tomorrow', 'origin', 'nrl']
# ['clockwinder', 'would', 'say', 'launch', 'common', 'tuesday', 'biog', 'late', 'david', 'taylor', 'untold', 'story', 'virtuous', 'mp']
# ['come', 'see', 'david', 'taylor', 'piopio', 'tomorrow', 'night']
# ['hey', 'david', 'taylor', 'nice', 'along', 'sir', 'friday', 'mushroom', 'f**k']
# ['like', 'shy', 'lizzy', 'bout', 'care', 'star', 'saturday', 'said', 'nigga', 'Instant', 'Message']
# ['french', 'montana', 'live', 'care', 'star', 'saturday', 'labor', 'day', 'wend', 'check']
# ['french', 'montana', 'live', 'care', 'star', 'saturday', 'labor', 'day', 'wend', 'check']
# ['beenie', 'man', 'performing', 'hostage', 'care', 'star', 'next', 'friday', 'Hey', 'hardest', 'afterparty', 'event', 'contact', 'ticket']
# ['french', 'montana', 'live', 'care', 'star', 'saturday', 'labor', 'day', 'wend', 'check']
# ['dmv', 'performing', 'live', 'care', 'star', 'saturday', 'w', 'big', 'band', 'shout', 'sunshine', 'benny']
# ['dmv', 'performing', 'live', 'care', 'star', 'saturday', 'w', 'big', 'band', 'shout', 'sunshine', 'benny']
# ['performing', 'care', 'star', 'hope', 'come']
# ['list', 'pa', 'romper', 'care', 'star', 'nightclub', 'st', 'time', 'since', 'toy', 'ready', 'dmv', 'official', 'host']
# ['time', 'seeing', 'wen', 'kaya', 'n', 'chante', 'went', 'care', 'star', 'stood', 'line', 'n', 'open', 'club', 'door', 'laughing', 'loud']
# ['yes', 'watch', 'degrassi', 'friday', 'yet', 'laughing', 'loud', 'awkward', 'campbell']
# ['still', 'watch', 'degrassi', 'friday', 'life', 'apparently', 'much']
# ['think', 'every', 'friday', 'Instant', 'Message', 'going', 'tweet', 'yay', 'degrassi', 'tonight', 'get', 'used']
# ['people', 'like', 'rd', 'year', 'senior', 'time', 'move', 'w', 'high', 'school', 'degrassi', 'age', 'forever']
# ['pretty', 'little', 'liar', 'time', 'missed', 'premier', 'tuesday', 'degrassi', 'shore', 'woo', 'occupied']
# ['sat', 'watching', 'degrassi', 'came', 'realisation', 'little', 'thing', 'aired']
# ['lover', 'since', 'th', 'grade', 'degrassi', 'day']
# ['going', 'holy', 'land', 'canada', 'tomorrow', 'lucky', 'meet', 'degrassi', 'gang', 'well', 'dream']
# ['rest', 'assures', 'watching', 'degrassi', 'loving', 'may', 'add']
# ['saw', 'degrassi', 'cause', 'missed', 'id', 'friday', 'cute']
# ...
# ['think', 'meg', 'may', 'well', 'one', 'clueless', 'hg', 'ever', 'big', 'brother', 'giving', 'devin', 'run', 'money', 'cluelessness', 'bye', 'bye']
# ['tell', 'going', 'see', 'paper', 'town', 'monday']
# ['love', 'thing', 'u', 'done', 'seth', 'rollins', 'monday', 'yes', 'whether', 'want', 'admit', 'say', 'need', 'authority']
# ['date', 'ace', 'super', 'eagle', 'midfielder', 'samuel', 'owarai', 'collapsed', 'died', 'pitch', 'national', 'stadium', 'lagos']
# ['one', 'day', 'country', 'philippine', 'egypt', 'afghanistan', 'infidel', 'murdered', 'muslim', 'tot', 'scot', 'tea', 'party', 'gdn']
# ['far', 'past', 'week', 'music', 'consisted', 'zac', 'brown', 'band', 'song', 'excited', 'concert', 'friday']
# ['nirvana', 'wild', 'overrated', 'smell', 'like', 'teen', 'spirit', 'way', 'goat', 'list', 'sat', 'whole', 'shitty', 'show', 'hear']
# ['ryan', 'braun', 'hit', 'th', 'career', 'home', 'run', 'top', 'st', 'inning', 'brewer', 'get', 'cub', 'coming', 'bat', 'versus', 'matt', 'garza']
# ['next', 'thursday', 'last', 'day', 'dunkin', 'trying', 'celebrate', 'laughing', 'loud']
# ['wondering', 'carly', 'fiorina', 'stance', 'amendment', 'wonder']
# ['josh', 'hamilton', 'scratched', 'ranger', 'lineup', 'wednesday', 'due', 'left', 'knee', 'soreness']
# ['kris', 'bryant', 'found', 'bomb', 'threat', 'called', 'sunday']
# ['kris', 'bryant', 'sneak', 'one', 'ryan', 'braun', 'glove', 'right', 'field', 'basket', 'th', 'year', 'cub']
# ['kris', 'bryant', 'take', 'garza', 'way', 'cub', 'fan', 'foot', 'bottom', 'mi', 'lvs', 'chc', 'brewer']
# ['k', 'boom', 'kris', 'bryant', 'tie', 'game', 'opposite', 'field', 'homer', 'th']
# ['kris', 'bryant', 'solo', 'shot', 'rf', 'bottom', 'cub', 'brewer', 'tied']
# ['big', 'brother', 'cbs', 'sister', 'station', 'tomorrow', 'football', 'make', 'list', 'change', 'bye', 'bye']
# ['go', 'rd', 'tied', 'one', 'thanks', 'kris', 'bryant', 'solo', 'homer']
# ['maybe', 'musical', 'ehh', 'sam', 'smith', 'much', 'amazing', 'c', 'mon', 'bethany']
# ['remembering', 'frank', 'gifford', 'say', 'reader', 'comment', 'death', 'nfl', 'hall', 'famer', 'former', 'monday', 'ni']
# ['jason', 'aldean', 'concert', 'thursday', 'night', 'guess', 'day', 'night', 'class']
# ['paul', 'mccartney', 'may', 'sung', 'jet', 'vote', 'tail']
# ['double', 'eviction', 'night', 'tomorrow', 'week', 'big', 'brother', 'one', 'night', 'got', 'see', 'tomorrow', 'bye', 'bye']
# ['mayweather', 'may', 'scumbag', 'never', 'come', 'close', 'losing', 'rousey']
# ['okay', 'imagine', 'dustin', 'johnson', 'choke', 'th', 'green', 'chamber', 'bay', 'move', 'ball', 'foot', 'two']
# ['seth', 'rollins', 'meet', 'greet', 'ticket', 'sale', 'barclays', 'center', 'go', 'let', 'ticket', 'go', 'retail']
# ['carly', 'fiorina', 'place', 'gop', 'poll', 'michigan', 'ahead', 'trump', 'week']
# ['may', 'allah', 'protect', 'muslim', 'ummah', 'oppressor']
# ['zac', 'brown', 'band', 'november', 'wait']
# ['asad', 'enough', 'kill', 'muslim', 'way', 'u', 'invite', 'United', 'States', 'America', 'kill', 'muslim', 'may', 'allah', 'punish', 'much', 'u', 'deserve']
# ['Instant', 'Message', 'going', 'sam', 'smith', 'thurs', 'fri']
# ['argh', 'going', 'miss', 'friday', 'another', 'david', 'price', 'start', 'hopefully', 'make', 'back', 'time', 'see', 'inning']
# ['someone', 'go', 'every', 'single', 'season', 'naruto', 'love', 'forever']
# ['ryan', 'braun', 'single', 'lead', 'th', 'rally', 'time', 'brewer']
# ['one', 'day', 'work', 'tomorrow', 'jason', 'aldean', 'concert', 'friday', 'monday', 'bill', 'game', 'friday', 'draft', 'sunday', 'bring', 'weekend']
# ['mention', 'going', 'blue', 'jay', 'game', 'friday', 'going', 'blue', 'jay', 'game', 'friday', 'david', 'price', 'pitching']
# ['hulk', 'hogan', 'th', 'scale', 'figure', 'pre', 'order', 'check', 'World', 'Wrestling', 'Entertainment', 'hulk', 'hogan']
# ['houston', 'selling', 'two', 'ticket', 'sam', 'smith', 'concert', 'friday', 'toyota', 'center', 'send', 'message', 'interested']
# ['hallowed', 'thy', 'name', 'iron', 'maiden', 'may', 'greatest', 'lyric', 'ever', 'written']
# ['ticket', 'jason', 'aldean', 'tomorrow', 'section', 'section', 'let', 'know', 'interested']
# ['good', 'morning', 'start', 'thursday', 'w', 'pop', '130815', 'naughty', 'boy', 'feat', 'sam', 'smith', 'la', 'la', 'la']
# ['rolling', 'stone', 'zone', 'monitor', 'sat', 'phone']
# ['direction', 'may', 'big', 'twitter', 'voting', 'go', 'whole', 'world', 'lose', 'kpop', 'bigger', 'fandom', 'direction', 'funeral']
# ['big', 'brother', 'tomorrow', 'going', 'good']
# ['yes', 'may', 'seem', 'difficult', 'believe', 'kpop', 'fan', 'literally', 'everywhere', 'though']
# ['shift', 'tomorrow', 'first', 'back', 'dunkin', 'cannot', 'sleep', 'feeling', 'little', 'sick', 'great']
# ['hamilton', 'scratched', 'versus', 'twin', 'sore', 'knee', 'ranger', 'scratched', 'josh', 'hamilton', 'wednesday']
# ['pat', 'dirt', 'top', 'grave', 'may', 'kpop', 'fan', 'rest', 'peace', 'direction', 'funeral']
# ['whoever', 'many', 'people', 'turned', 'kpop', 'whole', 'u', 'may', 'said', 'anyting', 'racist', 'people', 'ur', 'fandom']
# ['think', 'bo', 'afraid', 'scott', 'walker', 'might', 'cut', 'bo', 'pension', 'plan', 'pay', 'luxury', 'box', 'buck']
# ['may', 'fan', 'kpop', 'definitely', 'racist', 'dareunicorns', 'said', 'clarify']
# ['inhuman', 'rejection', 'muslim', 'bihar', 'may', 'push', 'community', 'towards', 'someone', 'may', 'change', 'political', 'equation', 'ever']
# ['naruto', 'way', 'go', 'man', 'new', 'episode', 'tomorrow']
# ['nothing', 'much', 'going', 'happen', 'naruto', 'tomorrow', 'going', 'intro', 'serious', 'shit', 'marada', 'go', 'crazy']
# ['final', 'frontier', 'fifteenth', 'studio', 'album', 'british', 'heavy', 'metal', 'band', 'iron', 'maiden', 'released']
# ['refusing', 'acknowledge', 'august', 'frank', 'ocean', 'release', 'album']
# ['may', 'asian', 'mean', 'automatically', 'like', 'ara', 'even', 'familiar', 'kpop', 'direction', 'funeral']
# ['direction', 'funeral', 'watch', 'kpop', 'fan', 'first', 'last', 'time', 'see', 'st', 'place', 'trend', 'thanks', 'u']
# ['started', 'liking', 'frank', 'ocean', 'drop', 'music', 'like', 'c', 'mon']
# ['may', 'fight', 'kpop', 'fan', 'never', 'ever', 'make', 'fun', 'someone', 'death']
# ['moment', 'corey', 'gamble', 'sandwiched', 'kris', 'caitlyn', 'jenner', 'kylie', 'th', 'birthday', 'party', 'sunday', 'night', 'almost']
# ['c', 'mon', 'guy', 'better', 'look', 'kpop']
# ['picked', 'naruto', 'going', 'go', 'see', 'tomorrow', 'laughing', 'loud']
# ['language', 'may', 'different', 'kpop', 'genre', 'western', 'music', 'stop', 'acting', 'like', 'outer', 'space']
# ['think', 'frank', 'gifford', 'think', 'guy', 'monday', 'night', 'football', 'playing', 'career']
# ['happy', 'th', 'birthday', 'one', 'dependable', 'human', 'being', 'know', 'may', 'light', 'never', 'go', 'dim', 'big', 'brother', 'friend']
# ['scott', 'walker', 'buck', 'cheaper', 'keep', 'repeated', 'inspiring', 'line', 'reasoning', 'wednesday', 'best', 'passive', 'aggressive', 'ever']
# ['thought', 'tribute', 'frank', 'gifford', 'first', 'class', 'around', 'sunday', 'thank', 'jason']
# ['calum', 'tweeted', 'lyric', 'back', 'march', 'finding', 'tweeted', 'nirvana', 'lyric', 'expect', 'bloom', 'cover', 'please']
# ['getting', 'thursday', 'almost', 'friday', 'mood', 'problem', 'strawberry', 'swing', 'frank', 'ocean', 'strictly', 'soul']
# ['dont', 'understand', 'hate', 'thing', 'co', 'st', 'place', 'kpop', 'different', 'honest', 'way', 'different', 'laughing', 'loud']
# ['president', 'chad', 'idriss', 'deby', 'said', 'tuesday', 'boko', 'haram', 'sect', 'longer', 'led', 'abubakar']
# ['hi', 'get', 'lounge', 'ticket', 'concert', 'thursday', 'th', 'october', 'london']
# ['work', 'day', 'need', 'vacation', 'start', 'tomorrow', 'first', 'stop', 'jason', 'aldean', 'sister', 'roommate']
# ['kpop', 'sound', 'like', 'disease', 'get', 'place', 'sun', 'definitely', 'shine', 'direction', 'funeral']
# ['would', 'suggested', 'song', 'raining', 'today', 'scott', 'walker', 'maybe', 'saturday']
# ['iron', 'maiden', 'new', 'single', 'tune', 'iron', 'maiden', 'speed', 'light']
# ['thursday', 'without', 'naruto']
# ['many', 'event', 'straight', 'outta', 'compton', 'movie', 'actually', 'took', 'place', 'ice', 'cube', 'separate', 'fact', 'fiction']
# ['went', 'woohoo', 'gig', 'mcg', 'gig', 'th', 'row', 'close', 'voice', 'gone', 'yelling']
# ['scott', 'walker', 'slip', 'st', 'ia', 'poll', 'w', 'caveat', 'poll', 'reflect', 'broader', 'grp', 'gop', 'voter', 'caucus', 'goer']
# ['according', 'rolling', 'stone', 'kurt', 'cobain', 'th', 'greatest', 'guitarist', 'time', 'somebody', 'actually', 'think', 'hurt']
# ['ticket', 'zac', 'brown', 'band', 'saturday', 'great', 'seat', 'make', 'anymore', 'going', 'sell', 'le', 'paid']
# ['mon', 'said', 'us', 'kpop', 'soft', 'foot', 'know', 'direction', 'funeral']
# ['boko', 'haram', 'new', 'leader', 'may', 'willing', 'negotiate', 'chadian', 'president']
# ['th', 'hole', 'seems', 'good', 'birdie', 'hole', 'dustin', 'johnson', 'birdie', 'th', 'st', 'hole', 'move', 'pga', 'champ']
# ['let', 'get', 'kardashian', 'caitlyn', 'jenner', 'take', 'selfie', 'dirty', 'water', 'ioc', 'may', 'change']
# ['wait', 'yankee', 'sweep', 'blue', 'jay', 'score', 'run', 'david', 'price', 'tomorrow', 'tulo', 'go']
# ['pic', 'taken', 'year', 'attended', 'gig', 'day', 'surreal']
# ['interesting', 'amount', 'muslim', 'condemn', 'isi', 'much', 'significant']
# ['hey', 'hey', 'checking', 'see', 'interest', 'sam', 'smith', 'ticket', 'cheap', 'show', 'saturday', 'erwin', 'center']
# ['understand', 'enjoy', 'ant', 'man', 'assure', 'start', 'time', 'return', 'tomorrow']
# ['like', 'see', 'spieth', 'rory', 'dustin', 'johnson', 'least', 'shot', 'sunday', 'kind', 'rooting', 'dj']
# ['ice', 'cube', 'talking', 'film', 'critic', 'jonathon', 'nettle', 'right', 'watch', 'interview', 'tomorrow', 'morning']
# ['big', 'brother', 'preempted', 'moved', 'accommodate', 'cowboy', 'game', 'thursday']
# ['guess', 'everyone', 'thursday', 'major', 'guessed', 'dustin', 'johnson', 'killing', 'hewillchokeon', 'sunday']
# ['dustin', 'johnson', 'often', 'nearly', 'man', 'major', 'eagle', 'par', 'th', 'share', 'early', 'pga', 'championship', 'lead', 'four']
# ['see', 'dustin', 'johnson', 'co', 'leader', 'right', 'take', 'serious', 'top', 'final', 'sunday', 'pga', 'championship']
# ['dustin', 'johnson', 'always', 'start', 'well', 'st', 'round', 'leader', 'must', 'fat', 'one', 'started']
# ['overflowing', 'conservative', 'christian', 'one', 'saturday']
# ['naruto', 'course', 'like', 'th', 'damn', 'time', 'watching', 'sao', 'damn', 'good']
# ['dustin', 'johnson', 'flyer', 'yet', 'need', 'stay', 'coke', 'saturday', 'night']
# ['hiroshima', 'fella', 'going', 'well', 'tipping', 'dustin', 'johnson', 'st', 'round', 'leader', 'see']
# ['may', 'miss', 'pennsylvania', 'miss', 'United', 'States', 'America', 'yet']
# ['World', 'Wrestling', 'Entertainment', 'summerslam', 'important', 'person', 'meet', 'greet', 'ticket', 'randy', 'orton', 'bid', 'end', 'date', 'tuesday', 'aug', 'World', 'Wrestling', 'Entertainment', 'ticket']
# ['yes', 'new', 'episode', 'got', 'released', 'sasuke', 'th', 'path', 'eye', 'sharingan', 'naruto', 'master', 'senjutsu']
# ['dustin', 'johnson', 'join', 'leader', 'birdie', 'th', 'hole', 'news', 'tiger', 'wood', 'made', 'turn', 'pga', 'champ']
# ['muslim', 'claiming', 'victim', 'oppression', 'quran', 'keep', 'perpetual', 'isolation']
# ['republican', 'presidential', 'candidate', 'carly', 'fiorina', 'ripped', 'donald', 'trump', 'incendiary', 'remark', 'megyn', 'kelly', 'friday', 'night']
# ['president', 'muhammadu', 'buhari', 'thursday', 'charged', 'new', 'head', 'nigerian', 'military', 'defeat', 'boko', 'haram']
# ['yeah', 'dustin', 'johnson', 'still', 'blow', 'sunday']
# ['opine', 'clinton', 'missing', 'e', 'ever', 'wonder', 'huma', 'lover', 'tie', 'united', 'brotherhood', 'muslim', 'may', 'sent', 'classified', 'one']
# ['want', 'love', 'darlin', 'refrain', 'end', 'walking', 'cold', 'november', 'rain', 'ay', 'eso', 'e', 'nirvana', 'b', 'tank']
# ['man', 'guy', 'could', 'sunday', 'dustin', 'johnson', 'obliterate', 'golf', 'course', 'better', 'make', 'yard']
# ['dustin', 'johnson', 'go', 'lead', 'anyone', 'take', 'bryan', 'advice', 'take', 'st', 'round', 'leader', 'pga', 'getting', 'excited']
# ['dustin', 'johnson', 'start', 'going', 'even', 'better', 'blow', 'saturday', 'sunday']
# ['dustin', 'johnson', 'best', 'st', 'round', 'player', 'time']
# ['dustin', 'johnson', 'move', 'clearly', 'strategy', 'get', 'far', 'ahead', 'penalty', 'stroke', 'sunday', 'matter']
# ['watching', 'monday', 'big', 'brother', 'clay', 'confused', 'evicted', 'last', 'thursday']
# ['television', 'rating', 'big', 'brother', 'lead', 'wednesday', 'mr', 'robinson', 'steady', 'ish', 'nbc', 'cbs', 'show', 'top', 'night']
# ['c', 'mon', 'randy', 'orton', 'one', 'like', 'meme', 'voltron']
# ['excited', 'see', 'sam', 'smith', 'saturday', 'laughing', 'loud']
# ['think', 'dustin', 'johnson', 'need', 'take', 'advice', 'zach', 'weekend', 'maybe', 'divine', 'intervention', 'need', 'sunday', 'usga']
# ['dustin', 'johnson', 'might', 'want', 'hold', 'something', 'back', 'thu', 'fri']
# ['thursday', 'new', 'naruto', 'come', 'today', 'filler']
# ['dustin', 'johnson', 'awesome', 'need', 'f**k', 'putt', 'hole', 'come', 'sunday', 'fold', 'like', 'lawn', 'chair', 'pressure', 'pga']
# ['dustin', 'johnson', 'leading', 'st', 'round', 'major', 'stop', 'heard']
# ['dustin', 'johnson', 'leading', 'early', 'tourny', 'mean', 'plenty', 'time', 'screw', 'ether', 'saturday', 'sunday']
# ['dustin', 'johnson', 'top', 'leaderboard', 'dammit', 'guess', 'mean', 'thursday', 'weekend', 'pga']
# ['pga', 'championship', 'dustin', 'johnson', 'leader', 'hole', 'rd', 'whistling', 'strait', 'play', 'progress']
# ['dustin', 'johnson', 'setting', 'pace', 'hope', 'wait', 'least', 'sunday', 'imploding']
# ['ice', 'cube', 'kevin', 'hart', 'back', 'first', 'trailer', 'ride', 'along', 'due']
# ['hi', 'decided', 'move', 'effort', 'upgrade', 'moto', 'g', 'g', 'lte', 'st', 'gen', 'directly', 'kitkat', 'lollipop', 'thanks']
# ['dustin', 'johnson', 'leading', 'pga', 'championship', 'rd', 'round', 'course', 'naturally', 'fall', 'apart']
# ['dustin', 'johnson', 'thursday', 'fri', 'player', 'weekend', 'come', 'handle', 'pressure', 'fold', 'like', 'lawnchair']
# ['dustin', 'johnson', 'leading', 'pga', 'championship', 'shock', 'call', 'still', 'sunday', 'need', 'finish', 'major']
# ['dustin', 'johnson', 'st', 'round', 'last']
# ['stay', 'away', 'kris', 'bryant', 'need', 'star', 'rd', 'baseman', 'caught', 'year', 'old']
# ['oh', 'conservative', 'even', 'ripped', 'frank', 'gifford', 'vietnam', 'died', 'may', 'asshole']
# ['anyone', 'selling', 'f**k', 'face', 'fest', 'single', 'day', 'ticket', 'saturday', 'please', 'let', 'know', 'care', 'frank', 'ocean', 'performance']
# ['news', 'kendrick', 'lamar', 'interview', 'n.w.a.', 'video', 'kendrick', 'lamar', 'sat', 'master', 'ceremony', 'ren', 'ice', 'cube', 'dr', 'cpr', 'habu']
# ['dustin', 'johnson', 'one', 'best', 'hole', 'player', 'tour', 'problem', 'worst', 'sunday', 'player', 'tour']
# ['wait', 'watch', 'august', 'everything', 'caitlyn', 'jenner', 'irritates', 'see', 'ad', 'reality', 'television', 'show']
# ['cub', 'fan', 'still', 'complaining', 'kris', 'bryant', 'didnt', 'come', 'til', 'may', 'number', 'dozen']
# ['saw', 'scott', 'walker', 'call', 'hillary', 'deceiver', 'chief', 'yes', 'today', 'throw', 'thursday']
# ['nothing', 'sat', 'good', 'koch', 'scott', 'walker', 'interest', 'cancer', 'benevolent', 'cause', 'big', 'c']
# ['estimated', 'muslim', 'britain', 'r', 'islamist', 'many', 'u', 'may', 'think', 'r', 'muslim', 'britain', 'islamist']
# ['thing', 'always', 'count', 'thursday', 'major', 'dustin', 'johnson', 'leading', 'tiger', 'wood', 'par']
# ['let', 'know', 'dustin', 'johnson', 'still', 'leading', 'back', 'nine', 'sunday']
# ['thursday', 'dustin', 'johnson', 'crushing', 'major', 'right']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### Data frame

# %%
pd.options.display.max_colwidth = 200
# %matplotlib inline
corpus = np.array([d["anot_tokens"] for d in dataset_raw])
labels = np.array(labels)
corpus_df = pd.DataFrame({"text": corpus,
                         "label": labels})
corpus_df = corpus_df[['text', 'label']]

# %% [markdown]
# ### Split data

# %%
from sklearn.model_selection import train_test_split
def split_train_validate_test(data, labels, train_valtest_ratio, validate_test_ratio, random_state=42):
    X_train, X_valtest, y_train, y_valtest = train_test_split(data, labels, test_size=train_valtest_ratio, random_state=random_state)
    X_validate, X_test, y_validate, y_test = train_test_split(X_valtest, y_valtest, test_size=validate_test_ratio, random_state=random_state)
    
    return X_train, X_validate, X_test, y_train, y_validate, y_test

# %% [markdown]
# ### Create vocab and encode tweets

# %%
vocab = build_vocab([d["anot_tokens"] for d in dataset_raw])

# %%
encoded_data = encode_data([d["anot_tokens"] for d in dataset_raw], vocab)

# %% [markdown]
# # Feature extraction

# %% [markdown]
# ## Pad encoded tweets

# %%
def pad_features(encoded, seq_length):
    features = np.zeros((len(encoded), seq_length), dtype = int)
    for i, review in enumerate(encoded):
        zeroes = list(np.zeros(seq_length - len(review)))
        new = zeroes + review        
        features[i,:] = np.array(new)
    
    return features

# %%
max_len = max(x for x in [len(d) for d in encoded_data])
features = pad_features(encoded_data, max_len)

# %%
x_train, x_validate, x_test, y_train, y_validate, y_test = split_train_validate_test(features, labels, 0.4, 0.5)

# %% [markdown]
# ## Embed vocabulary

# %%
def embed_vocab(vocab, embedding_dim = 300):
    hits, misses = 0, 0
    embedding_matrix = np.zeros((len(vocab) + 1, embedding_dim))
    for word, i in vocab.items():
        token = nlp(word)
        if token.has_vector:
            embedding_matrix[i] = token.vector
            hits += 1
        else:
            misses += 1
    
    print("Converted %d words (%d misses)" % (hits, misses))
    return embedding_matrix

# %%
embedding_matrix = embed_vocab(vocab)
# Out:
# Converted 29252 words (0 misses)

# %%
load_file = open("/home/ivan/Documents/git_repos/Sentiment-Analysis-on-Twitter/data/embedding_matrix.pickle", "rb")
embedding_matrix = pickle.load(load_file)
load_file.close()

# %%
file = open("/home/ivan/Documents/git_repos/Sentiment-Analysis-on-Twitter/data/embedding_matrix.pickle", "wb")
pickle.dump(embedding_matrix, file)
file.close()

# %% [markdown]
# ### Spacy glove

# %%
# doc_glove_vectors = np.array([nlp(str(doc)).vector for doc in corpus])

# %% [markdown]
# ### Dump features

# %%
write_file = open("/home/ivan/Documents/git_repos/Sentiment-Analysis-on-Twitter/data/spacy_features.pickle", "wb")
pickle.dump(feature_array, write_file)
write_file.close()

# %% [markdown]
# ### Load features

# %%
load_file = open("/home/ivan/Documents/git_repos/Sentiment-Analysis-on-Twitter/data/spacy_features.pickle", "rb")
features = pickle.load(load_file)
load_file.close()

# %% [markdown]
# # Model

# %% [markdown]
# ## Split features on train, validate and test

# %%
x_train, x_validate, x_test, y_train, y_validate, y_test = split_train_validate_test(features, labels, 0.3, 0.5)

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset# create Tensor datasets

train_data = TensorDataset(torch.from_numpy(x_train), torch.from_numpy(y_train))
valid_data = TensorDataset(torch.from_numpy(x_validate), torch.from_numpy(y_validate))
test_data = TensorDataset(torch.from_numpy(x_test), torch.from_numpy(y_test))

batch_size = 50

train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)
valid_loader = DataLoader(valid_data, shuffle=True, batch_size=batch_size)
test_loader = DataLoader(test_data, shuffle=True, batch_size=batch_size)

# %%
# obtain one batch of training data
# dataiter = iter(train_loader)
# sample_x, sample_y = dataiter.next()
# print('Sample input size: ', sample_x.size()) # batch_size, seq_length
# print('Sample input: \n', sample_x)
# print()
# print('Sample label size: ', sample_y.size()) # batch_size
# print('Sample label: \n', sample_y)

# %% [markdown]
# ## Model class

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Masking, Embedding
import tensorflow as tf
model = Sequential()
m = tf.keras.metrics.Recall()
# Embedding layer
model.add(
    Embedding(input_dim=len(vocab) + 1,
              input_length =28,
              output_dim=300,
              weights=[embedding_matrix],
              trainable=True,
              mask_zero=True))

# Masking layer for pre-trained embeddings
model.add(Masking(mask_value=0.0))

# Recurrent layer
model.add(LSTM(128, return_sequences=False, 
               dropout=0.01, recurrent_dropout=0.01))

# Fully connected layer
model.add(Dense(128, activation='relu'))

# Dropout for regularization
model.add(Dropout(0.5))

# Output layer
model.add(Dense(3, activation='softmax'))

# Compile the model
model.compile(
    optimizer='adam', loss=tf.keras.losses.Hinge(reduction="auto", name="hinge"), metrics=[m])

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

# Create callbacks
callbacks = [EarlyStopping(monitor='val_loss', patience=5), 
             ModelCheckpoint('../models/model.h5')]

# %% [markdown]
# ## Training the network

# %%
print(len(x_test))
print(len(x_train))
print(len(x_validate))
print(len(y_test))
print(len(y_train))
print(len(y_validate))
# Out:
# 5942
# 27724
# 5941
# 5942
# 27724
# 5941

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
y_validate = to_categorical(y_validate)

# %%
model.reset_states()
model.reset_metrics()
result = list()
for i in range(10):
    history = model.fit(x_train,  y_train, 
                    batch_size=2048, epochs=150,
                    callbacks=callbacks,
                    validation_data=(x_validate, y_validate))
    result.append(dict(zip(model.metrics_names, model.evaluate(x_test, y_test))))
# Out:
# Train on 27724 samples, validate on 5941 samples
# Epoch 1/150
# 27724/27724 [==============================] - 27s 964us/step - loss: 1.0484 - recall_12: 0.1944 - val_loss: 0.9876 - val_recall_12: 0.3661
# Epoch 2/150
# 27724/27724 [==============================] - 26s 938us/step - loss: 0.9633 - recall_12: 0.4298 - val_loss: 0.9377 - val_recall_12: 0.4706
# Epoch 3/150
# 27724/27724 [==============================] - 25s 908us/step - loss: 0.9267 - recall_12: 0.4984 - val_loss: 0.9201 - val_recall_12: 0.5189
# Epoch 4/150
# 27724/27724 [==============================] - 26s 938us/step - loss: 0.9102 - recall_12: 0.5356 - val_loss: 0.9110 - val_recall_12: 0.5490
# Epoch 5/150
# 27724/27724 [==============================] - 28s 1ms/step - loss: 0.8952 - recall_12: 0.5611 - val_loss: 0.9039 - val_recall_12: 0.5709
# Epoch 6/150
# 27724/27724 [==============================] - 28s 1ms/step - loss: 0.8862 - recall_12: 0.5799 - val_loss: 0.9023 - val_recall_12: 0.5874
# Epoch 7/150
# 27724/27724 [==============================] - 26s 936us/step - loss: 0.8785 - recall_12: 0.5947 - val_loss: 0.9014 - val_recall_12: 0.6005
# Epoch 8/150
# 27724/27724 [==============================] - 25s 890us/step - loss: 0.8729 - recall_12: 0.6065 - val_loss: 0.9024 - val_recall_12: 0.6111
# Epoch 9/150
# 27724/27724 [==============================] - 25s 885us/step - loss: 0.8683 - recall_12: 0.6161 - val_loss: 0.9019 - val_recall_12: 0.6200
# Epoch 10/150
# 27724/27724 [==============================] - 26s 928us/step - loss: 0.8653 - recall_12: 0.6241 - val_loss: 0.9001 - val_recall_12: 0.6274
# Epoch 11/150
# 27724/27724 [==============================] - 25s 914us/step - loss: 0.8627 - recall_12: 0.6309 - val_loss: 0.9001 - val_recall_12: 0.6338
# Epoch 12/150
# 27724/27724 [==============================] - 25s 912us/step - loss: 0.8596 - recall_12: 0.6370 - val_loss: 0.9022 - val_recall_12: 0.6394
# Epoch 13/150
# 27724/27724 [==============================] - 26s 927us/step - loss: 0.8573 - recall_12: 0.6422 - val_loss: 0.9007 - val_recall_12: 0.6443
# Epoch 14/150
# 27724/27724 [==============================] - 26s 946us/step - loss: 0.8547 - recall_12: 0.6469 - val_loss: 0.8979 - val_recall_12: 0.6489
# Epoch 15/150
# 27724/27724 [==============================] - 25s 907us/step - loss: 0.8531 - recall_12: 0.6512 - val_loss: 0.8994 - val_recall_12: 0.6529
# Epoch 16/150
# 27724/27724 [==============================] - 26s 923us/step - loss: 0.8507 - recall_12: 0.6551 - val_loss: 0.8994 - val_recall_12: 0.6566
# Epoch 17/150
# 27724/27724 [==============================] - 25s 912us/step - loss: 0.8496 - recall_12: 0.6586 - val_loss: 0.9001 - val_recall_12: 0.6600
# Epoch 18/150
# 27724/27724 [==============================] - 26s 925us/step - loss: 0.8484 - recall_12: 0.6617 - val_loss: 0.9002 - val_recall_12: 0.6630
# Epoch 19/150
# 27724/27724 [==============================] - 26s 922us/step - loss: 0.8475 - recall_12: 0.6646 - val_loss: 0.9000 - val_recall_12: 0.6658

# %%
result = model.evaluate(x_test, y_test)
dict(zip(model.metrics_names, result))
# Out:
# 5942/5942 [==============================] - 5s 887us/step
# {'loss': 0.9197255349528384, 'recall_12': 0.6655492186546326}
